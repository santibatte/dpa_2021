# %%
import pandas as pd

# %%
zip_code_income = pd.read_csv('zip_code_income_chicago.csv',sep=';').iloc[:, 0:2]

# %%
zip_code_income
# Out:
#     Location  Avg_income
# 0      60606    100377.0
# 1      60601     77374.0
# 2      60611     69889.0
# 3      60614     68324.0
# 4      60603     61815.0
# 5      60655     59849.0
# 6      60646     58232.0
# 7      60605     56151.0
# 8      60657     55647.0
# 9      60631     55316.0
# 10     60661     54698.0
# 11     60652     53120.0
# 12     60643     51305.0
# 13     60610     51294.0
# 14     60634     50042.0
# 15     60613     48381.0
# 16     60630     47905.0
# 17     60656     47512.0
# 18     60638     45173.0
# 19     60659     45064.0
# 20     60641     42182.0
# 21     60645     41438.0
# 22     60618     41355.0
# 23     60607     40972.0
# 24     60633     40792.0
# 25     60629     40279.0
# 26     60639     40165.0
# 27     60625     40083.0
# 28     60622     38487.0
# 29     60628     38210.0
# 30     60632     37406.0
# 31     60620     36334.0
# 32     60617     35534.0
# 33     60647     35283.0
# 34     60660     34293.0
# 35     60619     33631.0
# ...

# %%
# Tomamos como refrence group los primeros 15 , los que ganan mas de 50 mil al año:

# %%
zip_code_income.shape
# Out:
# (55, 2)

# %%
len(high_income_zip_code)
# Out:
# 15

# %%
medium_income_zip_cod

# %%
low_income_zip_code

# %%
high_income_zip_code=list(zip_code_income.iloc[0:16,0])

# %%
medium_income_zip_code=list(zip_code_income.iloc[16:34,0])

# %%
low_income_zip_code= list(zip_code_income.iloc[34:,0])

# %%
lista= list(zip_code_income['Location'])

# %%
classification = []
for val in lista:
    if val in high_income_zip_code:
        classification.append('High')
    elif val in medium_income_zip_code:
        classification.append('Medium')
    elif val in low_income_zip_code:
        classification.append('Low')
    else:
        classification.append('NA')

# %%
 zip_code_income['Classification']= classification

# %%
zip_code_income
# Out:
#     Location  Avg_income Classification
# 0      60606    100377.0           High
# 1      60601     77374.0           High
# 2      60611     69889.0           High
# 3      60614     68324.0           High
# 4      60603     61815.0           High
# 5      60655     59849.0           High
# 6      60646     58232.0           High
# 7      60605     56151.0           High
# 8      60657     55647.0           High
# 9      60631     55316.0           High
# 10     60661     54698.0           High
# 11     60652     53120.0           High
# 12     60643     51305.0           High
# 13     60610     51294.0           High
# 14     60634     50042.0           High
# 15     60613     48381.0           High
# 16     60630     47905.0         Medium
# 17     60656     47512.0         Medium
# 18     60638     45173.0         Medium
# 19     60659     45064.0         Medium
# 20     60641     42182.0         Medium
# 21     60645     41438.0         Medium
# ...

# %% [markdown]
# Leemos nuestros datos

# %%
food_inspections= pd.read_csv('../data/Food_inspections.csv')

# %%
#restaurant_zips=food_inspections['Zip'].dropna().astype('int')

# %%
pd.options.display.float_format = '{:,.0f}'.format

# %%
#food_inspections['Zip'== 60647]

# %%
food_inspections[food_inspections['Zip']== 60647]
# Out:
#         Inspection ID                                       DBA Name  \
# 0             2473009                     JENI'S SPLENDID ICE CREAMS
# 102           2320346                                          GIANT
# 158           2345301                          TABLE, DONKEY & STICK
# 189           2320739                                   BIXI BREWERY
# 191           2320696                            RESTAURANT 2 AMIGOS
# ...               ...                                            ...
# 215470         134320                   REAL TENOCHTITLAN RESTAURANT
# 215483         134347                            DONDE ZULY Y MAARTA
# 215497         134342                           ALBANY  FOOD  MARKET
# 215519         134344  CHICAGO INTERNATIONAL CHARTER SCHOOL BUCKTOWN
# 215549         134270                                      NUTRICLUB
#
#                             AKA Name  License #  Facility Type  \
# 0         JENI'S SPLENDID ICE CREAMS  2,767,260     Restaurant
# ...

# %%
len(food_inspections['Zip'].unique())
# Out:
# 113

# %%
zip_food_list=list(food_inspections['Zip'])

# %%
classification_food = []
for val in zip_food_list:
    if val in high_income_zip_code:
        classification_food.append('High')
    elif val in medium_income_zip_code:
        classification_food.append('Medium')
    elif val in low_income_zip_code:
        classification_food.append('Low')
    else:
        classification_food.append('Other')

# %%
pd.Series(classification_food).value_counts()
# Out:
# Medium    76978
# Low       71550
# High      60238
# Other      6860
# dtype: int64

# %%
food_inspections['Zip_income_classification'] = classification_food

# %%
food_inspections.columns
# Out:
# Index(['Inspection ID', 'DBA Name', 'AKA Name', 'License #', 'Facility Type',
#        'Risk', 'Address', 'City', 'State', 'Zip', 'Inspection Date',
#        'Inspection Type', 'Results', 'Violations', 'Latitude', 'Longitude',
#        'Location', 'Zip_income_classification'],
#       dtype='object')

# %%
food_inspections[['DBA Name','Zip','Zip_income_classification']]
# Out:
#                                                DBA Name    Zip  \
# 0                            JENI'S SPLENDID ICE CREAMS 60,647
# 1                                                PI18EN 60,608
# 2                                    CLAMP DOWN BURGERS 60,622
# 3                                        Fleming Branch 60,638
# 4                                              Pritzker 60,622
# ...                                                 ...    ...
# 215621                              MANNY'S CAFE MIDWAY 60,638
# 215622                                 WALGREENS #09001 60,601
# 215623                    CALIFORNIA PIZZA KITCHEN ASAP 60,602
# 215624  JACKSON SQUARE  NURSING & REHABILITATION CENTER 60,644
# 215625                                         COQ D OR 60,611
#
#        Zip_income_classification
# 0                         Medium
# 1                            Low
# 2                         Medium
# 3                         Medium
# 4                         Medium
# ...

# %% [markdown]
# Function Create Reference group

# %%
import pandas as pd


high_income_zip_code = [60606, 60601, 60611, 60614, 60603, 60655, 60646, 60605, 60657, 60631, 60661, 60652, 60643, 60610,60634, 60613]

medium_income_zip_code = [60630, 60656, 60638, 60659, 60641, 60645, 60618, 60607, 60633, 60629, 60639, 60625, 60622, 60628, 60632, 60620, 60617, 60647]

low_income_zip_code = [60660, 60619, 60651, 60640, 60615, 60626, 60604, 60616, 60623, 60608, 60636, 60649, 60644, 60609, 60612, 60602, 60637, 60624, 60621, 60653, 60654]


def create_reference_group(df):
    """
    df a df with zip code 
    returns a df with new column zip_income_classification which can be used as a reference group in aequitas analysis
    """
    
    zip_food_list=list(df['Zip'])
    
    classification_food = []
    
    for val in zip_food_list:
        if val in high_income_zip_code:
            classification_food.append('High')
        elif val in medium_income_zip_code:
            classification_food.append('Medium')
        elif val in low_income_zip_code:
            classification_food.append('Low')
        else:
            classification_food.append('Other')
    
    df['Zip_income_classification'] = classification_food
    
    return df

# %%
create_reference_group(food_inspections)
# Out:
#         Inspection ID                                         DBA Name  \
# 0             2473009                       JENI'S SPLENDID ICE CREAMS
# 1             2457202                                           PI18EN
# 2             2453552                               CLAMP DOWN BURGERS
# 3             2401262                                   Fleming Branch
# 4             2387142                                         Pritzker
# ...               ...                                              ...
# 215621         215236                              MANNY'S CAFE MIDWAY
# 215622         197282                                 WALGREENS #09001
# 215623         197256                    CALIFORNIA PIZZA KITCHEN ASAP
# 215624         176413  JACKSON SQUARE  NURSING & REHABILITATION CENTER
# 215625         205209                                         COQ D OR
#
#                                                AKA Name  License #  \
# ...
