# %% [markdown]
# # Notebook with test code

# %% [markdown]
# ---

# %% [markdown]
# ## Imports

# %% [markdown]
# ### Standard library imports

# %%
import yaml

import sys

from datetime import (date, datetime)

import os

import pickle

import re

# %% [markdown]
# ### Third party libraries

# %%
import boto3

import pandas as pd

# %% [markdown]
# ### Local application imports

# %%
sys.path.append("../")

# %%
# %load_ext autoreload
# %autoreload 2

from src.etl.ingesta_almacenamiento import (
    
    ## Functions
    get_client,
    ingesta_inicial,
    ingesta_consecutiva,
    get_s3_resource,
    guardar_ingesta,
    get_s3_credentials,
    
)


from src.utils.utils import (

    get_api_token

)

# %% [markdown]
# ---

# %% [markdown]
# ## AWS base examples

# %% [markdown]
# ### S3

# %% [markdown]
# #### Initial configuration

# %% [markdown]
# ##### Resource

# %% [raw]
# ses = boto3.session.Session(profile_name="robper_dpa")

# %% [raw]
# s3 = ses.resource("s3")

# %% [raw]
# [buck.name for buck in s3.buckets.all()]

# %% [raw]
# # este archivo yaml vive en tu conf/local/credentials.yaml
# # este va en src/utils general.py
# def read_yaml_file(yaml_file):
#     """ load yaml cofigurations """
#
#     config = None
#     try:
#         with open (yaml_file, 'r') as f:
#             config = yaml.safe_load(f)
#     except:
#         raise FileNotFoundError('Couldnt load the file')
#
#     return config

# %% [raw]
# # este va en src/utils general.py
# def get_s3_credentials(credentials_file):
#     credentials = read_yaml_file(credentials_file)
#     s3_creds = credentials['s3']
#
#     return s3_creds

# %% [markdown]
# ##### Client

# %%
s3_creds = get_s3_credentials("../conf/local/credentials.yaml")

session = boto3.Session(
    aws_access_key_id=s3_creds['aws_access_key_id'],
    aws_secret_access_key=s3_creds['aws_secret_access_key']
)
s3 = session.client('s3')

# %% [markdown]
# #### Connecting to existing bucket and viewing contents

# %%
bucket = "data-product-architecture-equipo-9"
key ="ingestion/consecutive"

# %%
objects = s3.list_objects_v2(Bucket=bucket, Prefix=key)['Contents']
objects
# Out:
# [{'Key': 'ingestion/consecutive/',
#   'LastModified': datetime.datetime(2021, 3, 18, 15, 36, 25, tzinfo=tzutc()),
#   'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#   'Size': 0,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'ingestion/consecutive/YEAR=2021/MONTH=03/consecutive_inspections_2021-03-18.pkl',
#   'LastModified': datetime.datetime(2021, 3, 19, 0, 16, 32, tzinfo=tzutc()),
#   'ETag': '"410a1b7bbf74d80e1c9e669ee727f7dd"',
#   'Size': 1047385,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'ingestion/consecutive/YEAR=2021/MONTH=04/consecutive_inspections_2021-04-10.pkl',
#   'LastModified': datetime.datetime(2021, 4, 11, 0, 55, 2, tzinfo=tzutc()),
#   'ETag': '"006092603520a926fef44b8e29a344b5"',
#   'Size': 946582,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'ingestion/consecutive/YEAR=2021/MONTH=04/consecutive_inspections_2021-04-12.pkl',
#   'LastModified': datetime.datetime(2021, 4, 12, 20, 7, 4, tzinfo=tzutc()),
#   'ETag': '"7b7070289f8b712d0c47c86c26cf6652"',
#   'Size': 13,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'ingestion/consecutive/YEAR=2021/MONTH=04/consecutive_inspections_2021-04-16.pkl',
#   'LastModified': datetime.datetime(2021, 4, 16, 16, 48, 26, tzinfo=tzutc()),
#   'ETag': '"089b7db843ecf9e07eaf65665e09818a"',
#   'Size': 111946,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'ingestion/consecutive/YEAR=2021/MONTH=04/consecutive_inspections_2021-04-17.pkl',
#   'LastModified': datetime.datetime(2021, 4, 17, 17, 30, 23, tzinfo=tzutc()),
#   'ETag': '"a64ffeeece213746ebd3d6268a038e53"',
#   'Size': 8238,
#   'StorageClass': 'STANDARD'}]

# %% [markdown]
# #### Reading pickle from S3

# %%
obj_path = [file["Key"] for file in objects if "2021-03-18" in file["Key"]][0]
obj_path
# Out:
# 'ingestion/consecutive/YEAR=2021/MONTH=03/consecutive_inspections_2021-03-18.pkl'

# %%
response = s3.get_object(
    Bucket=bucket,
    Key=obj_path
)
response
# Out:
# {'ResponseMetadata': {'RequestId': 'E86A0YYMF4A0X9CT',
#   'HostId': '1jaZMPS90cBuG9MyKMtf8Vc05wAofxaHM19GlIR0vrlou9F/5teRcXoPfJI3dYeWSWQybshI1mA=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': '1jaZMPS90cBuG9MyKMtf8Vc05wAofxaHM19GlIR0vrlou9F/5teRcXoPfJI3dYeWSWQybshI1mA=',
#    'x-amz-request-id': 'E86A0YYMF4A0X9CT',
#    'date': 'Sun, 18 Apr 2021 15:39:48 GMT',
#    'last-modified': 'Fri, 19 Mar 2021 00:16:32 GMT',
#    'etag': '"410a1b7bbf74d80e1c9e669ee727f7dd"',
#    'accept-ranges': 'bytes',
#    'content-type': 'binary/octet-stream',
#    'content-length': '1047385',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'AcceptRanges': 'bytes',
#  'LastModified': datetime.datetime(2021, 3, 19, 0, 16, 32, tzinfo=tzutc()),
#  'ContentLength': 1047385,
#  'ETag': '"410a1b7bbf74d80e1c9e669ee727f7dd"',
#  'ContentType': 'binary/octet-stream',
#  'Metadata': {},
#  'Body': <botocore.response.StreamingBody at 0x16ce68580>}

# %%
body = response["Body"].read()

# %% [raw]
# body

# %% [markdown]
# ---

# %%
pickle.loads(pickle.loads(body))
# Out:
# [{'inspection_id': '2484957',
#   'dba_name': 'SAWYER  (ANNEX)',
#   'aka_name': 'SAWYER',
#   'license_': '25231',
#   'facility_type': 'School',
#   'risk': 'Risk 1 (High)',
#   'address': '5247 S Spaulding ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60632',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass',
#   'latitude': '41.79756783709009',
#   'longitude': '-87.70597566195573',
#   'location': {'latitude': '-87.70597566195573',
#    'longitude': '41.79756783709009'}},
#  {'inspection_id': '2484950',
#   'dba_name': 'PHLOUR BAKERY AND CAFE',
#   'aka_name': 'PHLOUR BAKERY AND CAFE',
#   'license_': '2522179',
#   'facility_type': 'Bakery',
#   'risk': 'Risk 1 (High)',
#   'address': '1138 W BRYN MAWR AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60660',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass',
#   'violations': '40. PERSONAL CLEANLINESS - Comments: FOODHANDLERS NOT WEARING HAIR RESTRAINTS. MUST PROVIDE. | 53. TOILET FACILITIES: PROPERLY CONSTRUCTED, SUPPLIED, & CLEANED - Comments: FOUND NO LIDS FOR TRASH CANS INSIDE EMPLOYEE BI GENDER RESTROOMS. MUST PROVIDE. | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: FOUND EXHAUST/HOOD FILTERS NOT CLEAN AT STOVE AT REAR OF PREMISE. MUST CLEAN AND MAINTAIN.',
#   'latitude': '41.98373915183195',
#   'longitude': '-87.65964672940271',
#   'location': {'latitude': '-87.65964672940271',
#    'longitude': '41.98373915183195'}},
#  {'inspection_id': '2484919',
#   'dba_name': 'SOUP & SCOOPS, LLC',
#   'aka_name': 'SOUP & SCOOPS',
#   'license_': '2569510',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '6709 N OLMSTED AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60631',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Fail',
#   'violations': '1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOWLEDGE, AND PERFORMS DUTIES - Comments: PERSON IN CHARGE DOES NOT HAVE A CITY OF CHICAGO SANITATION CERTIFICATE. PRIORITY FOUNDATION VIOLATION    NO CITATION ISSUED | 2. CITY OF CHICAGO FOOD SERVICE SANITATION CERTIFICATE - Comments: FOUND NO CERTIFIED FOOD MANAGER ON SITE WHILE TCS FOODS (SOUPS, SANDWICHES, PANINI ETC) ARE BEING PPREPARED AND SERVED. INSTRUCTED PERSON IN CHARGE, A CERTIFIED FOOD MANAGER WITH CITY OF CHICAGO FOODSERVICE SANITATION CERTIFICATE MUST BE PRESENT AT ALL TIMES WHAN HANDLING TCS FOODS. AND CERTIFICATES MUST BE POSTED ON PREMISE. PRIORITY FOUNDATION VIOLATION 7-38-012    CITATION ISSUED    | 3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: FOUND NO EMPLOYEE HEALTH POLICY/TRAINING ON SITE. INSTRUCTED TO PROVIDE A SIGNED EMPLOYEE HEALTH POLICY FOR EACH EMPLOYEE.   PRIORITY FOUNDATION VIOLATION  7-38-010     NO CITATION ISSUED | 10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: FOUND NO HANDSOAP AVAILABLE AT HANDSINK IN FRONT PREP AND IN REAR PREP AREA. INSTRUCTED TO PROVIDE. (CORRECTED ON SITE) PRIORITY FOUNDATION VIOLATION   7-38-030 (C)   CITATION ISSUED | 10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: OBSERVED NO HAND DRYING DEVICE OR PAPER TOWEL AVAILABLE AT HANDSINK IN FRONT PREP AREA. INSTRUCTED TO PROVIDE.  (CORRECTED ON SITE) PRIORITY FOUNDATION 7-38-030 (C)  NO CITATION ISSUED.  (CONSOLIDATED WITH THE ABOVE CITATION). | 35. APPROVED THAWING METHODS USED - Comments: OBSERVED IMPROPER THAWING POCEDURE ON FROZEN SOUP. INSTRUCTED MANAGEMENT, THAWING MUST OCCUR UNDER REFRIGERATION THAT MAINTAINS THE FOOD TEMPERATURE AT 41.0F OR LESS OR COMPLETELY SUBMERGED UNDER RUNNING WATER OR THAWED IN A MICROWAVE OVEN AND IMMEDIATELY TRANSFERRED TO CONVENTIONAL COOKING EQUIPMENT  WITH NO INTERRUPTION IN THE PROCESS. INSTRUCTED TO MAINTAIN CORRECT THAWING PROCEDURES. | 36. THERMOMETERS PROVIDED & ACCURATE - Comments: INSTRUCTED TO PROVIDE THERMOMETER VISIBLE INSIDE ALL REACH-IN COOLERS. | 37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER - Comments: NOTED PREPACKAGED SOUP ON DISPLAY COOLER WITH MISSING INGREDIENTS. INSTRUCTED TO PROVIDE. (IF MADE FROM TWO OR MORE INGREDIENTS, A LIST OF INGREDIENTS AND SUBINGREDIENTS IN DESCENDING ORDER.PREDOMINANCE BY WEIGHT). | 38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: INSTRUCTED TO RODENT PROOFED BOTTOM OF FRONT ENTRANCE AND REAR EXIT DOOR. | 39. CONTAMINATION PREVENTED DURING FOOD PREPARATION, STORAGE & DISPLAY - Comments: OBSERVED FOOD BOXES/CONTAINERS IN BASEMENT DRY STORAGE AREA ARE STORED UNDER SOME EXPOSED SEWAGE PIPES. FOOD CONTAINERS MUST BE REMOVE FROM SOME EXPOSED SEWAGE PIPES OR PROPERLY ENCLOSE  SEWER LINES THAT ARE NOT SHIELDED TO INTERCEPT POTENTIAL DRIPS. INSTRUCTED TO PROPERLY ENCLOSE  SEWER LINES THAT ARE NOT SHIELDED TO INTERCEPT POTENTIAL DRIPS OR REMOVE THE SAID BOXES. | 48. WAREWASHING FACILITIES: INSTALLED, MAINTAINED & USED; TEST STRIPS - Comments: INSTRUCTED TO PROVIDE 3 WORKING DRAIN STOPPERS FOR 3 COMPARTMENT SINK. | 51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICES - Comments: BACKFLOW PREVENTER DEVICE NOT LOCATED  BEHIND COFFEE MACHINE IN REAR PREP AREA               INSTRUCTED TO INSTALL SO THAT IT CAN BE LOCATED TO BE SERVICED AND MAINTAINED. | 54. GARBAGE & REFUSE PROPERLY DISPOSED; FACILITIES MAINTAINED - Comments: INSTRUCTED TO PROVIDE LID/COVER FOR GARBAGE RECEPTACLE IN SERVING AREA. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: INSTRUCTED TO CLEAN AND MAINTAIN CEILING VENT COVER INSIDE WASHROOM. | 57. ALL FOOD EMPLOYEES HAVE FOOD HANDLER TRAINING - Comments: FOOD HANDLER (S) WITH NO PROOF OF FOOD HANDLER TRAINING CERTIFICATE.  INSTRUCTED TO PROVIDE CERTIFICATE FOR EACH EMPLOYEE.  | 58. ALLERGEN TRAINING AS REQUIRED - Comments: FOUND NO APPROVED ALLERGEN TRAINING CERTIFICATE  IN ACCORDANCE WITH PA 100-0367 ON SITE.  INSTRUCTED ANY PERSON WIT ...
#   'latitude': '42.002389738392516',
#   'longitude': '-87.81707622356394',
#   'location': {'latitude': '-87.81707622356394',
#    'longitude': '42.002389738392516'}},
#  {'inspection_id': '2484935',
#   'dba_name': 'STARBUCKS COFFEE #13710',
#   'aka_name': 'STARBUCKS',
#   'license_': '1843207',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 2 (Medium)',
#   'address': '30 W ERIE ST ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60654',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Canvass Re-Inspection',
#   'results': 'Pass',
#   'violations': '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: MUST REPAIR TORN DOOR GASKET ON 2-DOOR REACH IN COOLER IN REAR, INSTRUCTED TO MAINTAIN. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: MUST CLEAN WATER AND LOOSE DEBRIS FROM FLOORS THROUGHOUT FRONT & REAR PREP AREAS. INSTRUCTED TO CLEAN AND MAINTAIN.',
#   'latitude': '41.89416541426283',
#   'longitude': '-87.62938902777785',
#   'location': {'latitude': '-87.62938902777785',
#    'longitude': '41.89416541426283'}},
#  {'inspection_id': '2484967',
#   'dba_name': 'COCHIAROS PIZZA #4',
#   'aka_name': 'COCHIAROS PIZZA',
#   'license_': '51686',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '3555 N CENTRAL AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60634',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass w/ Conditions',
#   'violations': "5. PROCEDURES FOR RESPONDING TO VOMITING AND DIARRHEAL EVENTS - Comments: FOUND NO PROCEDURE/PLAN FOR RESPONDING TO VOMITING AND DIARRHEAL EVENTS. INSTRUCTED TO PROVIDE AND MAINTAIN REQUIRED PROCEDURE/PLAN AND APPROPRIATE SUPPLIES OR KIT. (NECESSARY ITEMS AT A MINIMUM: GLOVES, FACE MASKS, DISPOSABLE MOPS AND APPROPRIATE SANITIZER/SPRAY THAT IS EFFECTIVE AGAINST NOROVIRUS). PRIORITY FOUNDATION VIOLATION 7-38-005,NO CITATION ISSUED. | 38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: OBSERVED APPROX:1/4' INCH OPENING ALL ACROSS THE BOTTOM OF REAR EXIT DOOR.MUST PEST PROOF DOOR TO PREVENT PEST ENTRY AND MAINTAIN. | 40. PERSONAL CLEANLINESS - Comments: OBSERVED EMPLOYEE WITH NO HAIR RESTRAINT AT FRONT FOOD PREP AREA. INSTRUCTED MANAGER TO PROVIDED HAIR RESTRAINTS FOR ALL EMPLOYEES IN THE FOOD PREP AREA. | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: OBSERVED RUST ON THE WIRE STORAGE RACKS IN THE WALK-IN COOLER.INSTRUCTED TO REMOVE RUSTS AND REPAINT OR REPLACE THE SHELVES AND MAINTAIN. | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: OBSERVED A TORN DOOR GASKET INSIDE OF THE 2 DOOR PIZZA PREP COOLER.INSTRUCTED TO REPLACE THE TORN DOOR GASKET. | 49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: INSTRUCTED TO DETAIL CLEAN INTERIOR BOTTOM COMPARTMENTS OF DEEP FRYERS,COOLERS,SIDES OF HOT COOKING EQUIPMENTS,TOP OF PIZZA OVEN AND STORAGE SHELFS AT REAR KITCHEN FOOD PREP AREA TO REMOVE EXCESSIVE GREASE BUILD-UP. | 51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICES - Comments: BACKFLOW PREVENTION DEVICE NOT LOCATED AT ICE MACHINE.MUST INSTALL SO BACKFLOW PREVENTION DEVICE MAY BE LOCATED TO BE SERVICED AND MAINTAINED. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED DIRTY FLOORS WITH EXCESSIVE GREASE DRIED UP FOOD DEBRIS UNDERNEATH THE KITCHEN COOKING EQUIPMENTS.MUST CLEAN IN DETAIL AND MAINTAIN. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: INSTRUCTED TO DETAIL CLEAN AND ORGANIZE REAR KITCHEN/DISHWASHING AREA AND REMOVE UNNECESSARY ARTICLES ON TOP OF THE WALK-IN-COOLER DUE TO POTENTIAL PEST HARBORAGE AND ELEVATE MOPS,BROOMS CLEANING EQUIPMENTS OFF THE FLOOR AT LEAST 6' INCHES FOR EASE IN CLEANING. | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: INSTRUCTED TO DETAIL CLEAN AND MAINTAIN CEILING VENTILATION COVERS WITH DUST ACCUMULATION ABOVE THE FRONT PREP AREA. | 58. ALLERGEN TRAINING AS REQUIRED - Comments: ALLERGEN TRAINING IS REQUIRED FOR ALL EMPLOYEES THAT HAVE A CITY OF CHICAGO FOOD SANITATION CERTIFICATE. INSTRUCTED TO COMPLETE TRAINING AND MAINTAIN CERTIFICATE ON SITE. ",
#   'latitude': '41.94571656305218',
#   'longitude': '-87.76660329761108',
#   'location': {'latitude': '-87.76660329761108',
#    'longitude': '41.94571656305218'}},
#  {'inspection_id': '2484954',
#   'dba_name': 'SAWYER (MAIN)',
#   'aka_name': 'SAWYER',
#   'license_': '2040692',
#   'facility_type': 'School',
#   'risk': 'Risk 1 (High)',
#   'address': '5248 S SAWYER AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60632',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass',
#   'latitude': '41.7975215482685',
#   'longitude': '-87.70504311350855',
#   'location': {'latitude': '-87.70504311350855',
#    'longitude': '41.7975215482685'}},
#  {'inspection_id': '2484944',
#   'dba_name': 'EDGEWATER MEXICAN CAFE',
#   'aka_name': 'EDGEWATER MEXICAN CAFE',
#   'license_': '2615664',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '1055 W BRYN MAWR AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60660',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass',
#   'violations': '37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER - Comments: FOUND BULK FOOD NOT LABELED INSIDE LARGE STORAGE CONTAINERS.(FLOUR,SUGAR,BEANS,ETC.)MUST LABEL.',
#   'latitude': '41.9835594257736',
#   'longitude': '-87.65738202407279',
#   'location': {'latitude': '-87.65738202407279',
#    'longitude': '41.9835594257736'}},
#  {'inspection_id': '2484958',
#   'dba_name': 'AM THAI RESTAURANT',
#   'aka_name': 'AM THAI RESTAURANT',
#   'license_': '2501814',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '3254 W MONTROSE AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60618',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Out of Business',
#   'latitude': '41.96127134510051',
#   'longitude': '-87.71046266805209',
#   'location': {'latitude': '-87.71046266805209',
#    'longitude': '41.96127134510051'}},
#  {'inspection_id': '2484941',
#   'dba_name': 'STARBUCK COFFEE #2615',
#   'aka_name': 'STARBUCKS COFFEE',
#   'license_': '1357035',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 2 (Medium)',
#   'address': '2159 W BELMONT AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60618',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass w/ Conditions',
#   'violations': "5. PROCEDURES FOR RESPONDING TO VOMITING AND DIARRHEAL EVENTS - Comments: OBSERVED NO WRITTEN PROCEDURES OR SUPPLIES FOR RESPONDING TO VOMITING OR DIARRHEAL EVENTS. SUPPLIES MUST INCLUDE ADEQUATE SANITIZER THAT ELIMINATES NOROVIRUS. INSTRUCTED FACILITY TO PROVIDE CLEAN UP POLICY AND SUPPLIES TO PROPERLY HANDLE VOMIT AND DIARRHEAL SPILLS ON SITE. PRIORITY FOUNDATION VIOLATION #7-38-005. NO CITATION ISSUED. | 38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: OBSERVED A 1/4' GAP ON THE UPPER LEFT CORNER AND BOTTOM LEFT SIDE OF THE FRONT ENTRANCE DOOR. MUST PROVIDE A TIGHT FITTING SEAL AT ALL OUTER OPENINGS TO PREVENT THE ENTRY OF PESTS. | 48. WAREWASHING FACILITIES: INSTALLED, MAINTAINED & USED; TEST STRIPS - Comments: FACILITY USES HIGH TEMPERATURE SANITIZING DISH MACHINE AND DOESN'T HAVE PROPER TEMPERATURE MEASURING IRREVERSIBLE REGISTERING TEMPERATURE INDICATOR THAT SHALL BE PROVIDED AND READILY ACCESSIBLE FOR MEASURING THE UTENSIL SURFACE TEMPERATURE. INSTRUCTED TO PROVIDE. PRIORITY FOUNDATION VIOLATION 7-38-005 NO CITATION ISSUED | 53. TOILET FACILITIES: PROPERLY CONSTRUCTED, SUPPLIED, & CLEANED - Comments: OBSERVED NO COVERED RECEPTACLES IN BOTH UNISEX EMPLOYEE/PUBLIC TOLIET ROOMS. INSTRUCTED TO PROVIDE. | 57. ALL FOOD EMPLOYEES HAVE FOOD HANDLER TRAINING - Comments: OBSERVED NO FOOD HANDLER CERTIFICATES FOR EMPLOYEES ON SITE. INSTRUCTED TO PROVIDE AND MAINTAIN.",
#   'latitude': '41.939404858528796',
#   'longitude': '-87.68307714601951',
#   'location': {'latitude': '-87.68307714601951',
#    'longitude': '41.939404858528796'}},
#  {'inspection_id': '2484986',
#   'dba_name': 'CAFE ROM',
#   'aka_name': 'CAFE ROM',
#   'license_': '2423760',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 2 (Medium)',
#   'address': '180 N STETSON AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60601',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Out of Business',
#   'latitude': '41.885367821459624',
#   'longitude': '-87.62244720125689',
#   'location': {'latitude': '-87.62244720125689',
#    'longitude': '41.885367821459624'}},
#  {'inspection_id': '2484961',
#   'dba_name': 'JEWEL FOOD STORE',
#   'aka_name': 'JEWEL FOOD STORE',
#   'license_': '2320250',
#   'facility_type': 'Grocery Store',
#   'risk': 'Risk 1 (High)',
#   'address': '1763 W HOWARD ST ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60626',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Complaint Re-Inspection',
#   'results': 'Pass',
#   'violations': "38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments:  OUTER OPENING NOT PROTECTED.HOLE AT BOTTOM OF THE ROLL UP DOOR AT REAR DELIVERY AREA.SEAL AND MAINTAIN TO MINIMIZE PEST ENTRY  | 53. TOILET FACILITIES: PROPERLY CONSTRUCTED, SUPPLIED, & CLEANED - Comments: ALL BLACK SMALL RECEPTACLE CONTAINERS INSIDE THE STALL IN WOMEN'S WASHROOM OF STAFF AND CUSTOMER'S MUST HAVE A LIDS. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED EXPANDING SPRAY FOAM USED AS A SEALANT FOR OPENINGS AROUND CEILING PIPES BEHIND STOVE AND ABOVE THE HIGH TEMP DISHMACHINE. MUST REMOVE. SURFACE MUST BE SMOOTH AND CLEANABLE.",
#   'latitude': '42.01928855008811',
#   'longitude': '-87.67505850938775',
#   'location': {'latitude': '-87.67505850938775',
#    'longitude': '42.01928855008811'}},
#  {'inspection_id': '2484975',
#   'dba_name': "TONY'S ITALIAN DELI",
#   'aka_name': "TONY'S ITALIAN DELI",
#   'license_': '429',
#   'facility_type': 'Grocery Store',
#   'risk': 'Risk 1 (High)',
#   'address': '6708 N NORTHWEST HWY ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60631',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass',
#   'violations': "36. THERMOMETERS PROVIDED & ACCURATE - Comments: INSTRUCTED TO PROVIDE THERMOMETER VISIBLE INSIDE ALL COOLERS (REACH-IN COOLER, DELI COOLER, WALK-IN COOLER ETC). | 37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER - Comments: INSTRUCTED TO PROPERLY LABEL FOOD CONTAINERS IDENTIFIED WITH COMMON NAME (SALT, SUGAR, CHILI POWDER ETC) | 45. SINGLE-USE/SINGLE-SERVICE ARTICLES: PROPERLY STORED & USED - Comments: SINGLE SERVICE ITEMS (PANS/COVER) IN STORAGE RACKS (IN FOOD PREP AREA) MUST BE STORED UPSIDE DOWN/INVERTED TO PREVENT CONTAMINATION. | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: INSTRUCTED TO PROPERLY STORE BOXES 6' OFF THE FLOOR INSIDE WALK-IN COOLER. | 48. WAREWASHING FACILITIES: INSTALLED, MAINTAINED & USED; TEST STRIPS - Comments: INSTRUCTED TO FIX SLOW DRAINING 3 COMPARTMENT SINK IN REAR MAIN PREP AREA.",
#   'latitude': '42.00289469259332',
#   'longitude': '-87.81656422345733',
#   'location': {'latitude': '-87.81656422345733',
#    'longitude': '42.00289469259332'}},
#  {'inspection_id': '2484979',
#   'dba_name': 'POTBELLY SANDWICH  WORKS',
#   'aka_name': 'POTBELLY SANDWICH  WORKS',
#   'license_': '1913925',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '959 W DIVERSEY PKWY ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60614',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Canvass Re-Inspection',
#   'results': 'Pass w/ Conditions',
#   'violations': '2. CITY OF CHICAGO FOOD SERVICE SANITATION CERTIFICATE - Comments: OBSERVED NO ONE ON SITE WITH A CITY OF CHICAGO CERTIFED FOOD MANAGER CERTIFICATE WHILE TIME/TEMPERATURE TCS FOODS INCLUDING DELI MEAT ARE BEING PREPARED AND SERVED. PRIORITY FOUNDATION VIOLATION 7-38-012 CITATION ISSUED | 16. FOOD-CONTACT SURFACES: CLEANED & SANITIZED - Comments: OBSERVED PLASTIC CUTTING BOARD WITH DARK GROOVES. MUST REPLACE CUTTING BOARD. | 33. PROPER COOLING METHODS USED; ADEQUATE EQUIPMENT FOR TEMPERATURE CONTROL - Comments: OBSERVED SMALL REACH IN REFRIGERATOR/COLD HOLD UNIT ON PREPARATION LINE NOT MAINTAINING 41F OR LESS. NO TIME TEMPERATURE CONTROLLED FOODS WERE FOUND INSIDE AT TIME OF INSPECTION. REFRIGERATION UNIT WAS TAGGED. PRIORITY 7-38-005 NO CITATION ISSUED. | 36. THERMOMETERS PROVIDED & ACCURATE - Comments: OBSERVED NO THERMOMETERS WITHIN REACH IN REFRIGERATORS ON PREP LINE. MUST PROVIDE AND MAINTAIN WORKING THERMOMETERS IN ALL REACH IN REFRIGERATION UNITS. THERMOMETERS MUST BE EASY TO LOCATE AND CHECK TO MAKE SURE THE REFRIGERATION UNITS ARE 41F OR LESS AT ALL TIMES. | 49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: OBSERVED ALL EXTERIOR OF REACH IN COOLERS, INCLUDING HANDLES NEED TO BE CLEANED IN DETAIL AND MAINTAINED. OBSERVED INTERIOR OF REACH IN ICE CREAM FREEZER WITH FOOD SPILLS. CLEAN AND MAINTAIN. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED FLOORS AND WALLS ON PREP LINE UNCLEAN WITH GRIME AND FOOD DEBRIS. ALL COOLERS NEED TO BE PULLED AWAY FROM WALLS AND FLOORS AND WALLS UNDER AND BEHIND COOLERS NEED TO BE CLEANED IN DETAIL AND MAINTAINED. | 59. PREVIOUS PRIORITY FOUNDATION VIOLATION CORRECTED - Comments: OBSERVED PREVIOUS PRIORITY FOUNDATION VIOLATIONS FROM REPORT #1913925 DATED 2/10/21 NOT CORRECTED INCLUDING VIOLATION # 60 PREVIOUS CORE VIOLATIONS FROM REPORT #235661 DATED 1/10/2020:VIOLATION #47 VENT WHITE HOSE IN SMALL COOLER UNDER THE FRONT COUNTER EXTREMELY DIRTY WITH FOOD DEBRIS AND GRIME. INSTRUCTED TO REPLACE OR CLEAN SAID HOSE. VIOLATION #49 FOOD AND GRIME INSIDE ALL SMALL REACH IN COOLERS WITH LIQUID SPILLAGE. MUST CLEAN AND MAINTAIN. PRIORITY VIOLATION 7-42-090 CITATION ISSUED',
#   'latitude': '41.93252953939086',
#   'longitude': '-87.6537938531344',
#   'location': {'latitude': '-87.6537938531344',
#    'longitude': '41.93252953939086'}},
#  {'inspection_id': '2484930',
#   'dba_name': 'EL PAISANO TACOS INC',
#   'aka_name': 'EL PAISANO TACOS',
#   'license_': '2501058',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '2429 W DIVISION ST ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60622',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Complaint',
#   'results': 'Pass',
#   'violations': '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: FOUND ALL CUTTING BOARDS STAINED WITH DEEP GROOVES. MUST REPlACE | 53. TOILET FACILITIES: PROPERLY CONSTRUCTED, SUPPLIED, & CLEANED - Comments: FOUND NO COVERED GARBAGE RECEPTACLE LOCATED IN UNISEX WASHROOM. MUST PROVIDE ',
#   'latitude': '41.90289443680921',
#   'longitude': '-87.68823386858675',
#   'location': {'latitude': '-87.68823386858675',
#    'longitude': '41.90289443680921'}},
#  {'inspection_id': '2484945',
#   'dba_name': 'IMPERIAL RESTAURANT',
#   'aka_name': 'IMPERIAL RESTAURANT',
#   'license_': '2771659',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '2100 S ARCHER AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60616',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'License',
#   'results': 'Pass w/ Conditions',
#   'violations': "3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: 2-102.14(O) OBSERVED NO EMPLOYEE HEALTH POLICY ON SITE. INSTRUCTED TO PROVIDE. PRIORITY FOUNDATION 7-38-010. | 10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: 6-301.14 OBSERVED SOME HAND WASHING SINKS IN THE FOOD PREP AREA NEED HAND WASHING SIGNS. INSTRUCTED TO PROVIDE. | 37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER - Comments: 3-302.12 OBSERVED DRY STORAGE BINS NOT LABELED WITH PRODUCT NAME LOCATED IN THE DRY STORAGE ROOM. INSTRUCTED TO LABEL ALL DRY STORAGE BINS WITH THE COMMON NAME OF PRODUCT. | 38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: 6-202.15 OBSERVED ONE INCH GAP IN BETWEEN THE FRONT ENTRANCE DOORS. INSTRUCTED TO SEAL FRONT ENTRANCE DOORS SO THAT THE FRONT ENTRANCE DOORS ARE TIGHT FITTING AND RODENT PROOFED. | 48. WAREWASHING FACILITIES: INSTALLED, MAINTAINED & USED; TEST STRIPS - Comments: 4-603.15 OBSERVED POTS TOO LARGE TO BE SUBMERGED INSIDE OF THE 3 COMPARTMENT SINK. INSTRUCTED TO PROVIDE AN ALTERNATIVE MANUAL WAREWASHING PROCEDURE OR INSTALL A LARGER 3 COMPARTMENT SINK OR REMOVE POTS THAT ARE TOO LARGE TO BE FULLY SUBMERGED IN ORDER TO PROPERLY WASH RINSE AND SANITIZE. | 53. TOILET FACILITIES: PROPERLY CONSTRUCTED, SUPPLIED, & CLEANED - Comments: 5-501.17 OBSERVED A COVERED RECEPTACLE IS NEEDED INSIDE OF THE EMPLOYEE TOILET ROOM AND INSIDE OF THE WOMEN'S TOILET ROOM. INSTRUCTED TO PROVIDE. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: 6-501.12 OBSERVED ACCUMULATED DIRT DEBRIS UNDER THE AQUATIC TANKS LOCATED BY THE FOOD PREP AREA ENTRANCE AND UNDER THE REFRIGERATION UNITS LOCATED IN THE FOOD PREP AREA. OBSERVED ACCUMULATED FOOD AND GREASE DEBRIS INSIDE OF THE FRYERS. OBSERVED ACCUMULATED DEBRIS ON THE SHELVES IN BOTH WALK IN COOLERS LOCATED IN THE FOOD PREP AREA. INSTRUCTED TO CLEAN AND SANITIZE ALL. | 58. ALLERGEN TRAINING AS REQUIRED - Comments: 2-102.13 OBSERVED THE CITY OF CHICAGO FOOD SERVICE SANITATION MANAGER WITHOUT THE REQUIRED ALLERGEN TRAINING CERTIFICATE. INSTRUCTED TO MEET REQUIREMENT.",
#   'latitude': '41.854333954143414',
#   'longitude': '-87.63204756042012',
#   'location': {'latitude': '-87.63204756042012',
#    'longitude': '41.854333954143414'}},
#  {'inspection_id': '2484973',
#   'dba_name': 'HILLTOP FAMILY RESTAURANT',
#   'aka_name': 'HILLTOP FAMILY RESTAURANT',
#   'license_': '2652370',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '2800 W FOSTER AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60625',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Canvass Re-Inspection',
#   'results': 'Fail',
#   'violations': "44. UTENSILS, EQUIPMENT & LINENS: PROPERLY STORED, DRIED, & HANDLED - Comments: 4-903.11  OBSERVED WATER LEAKING FROM THE CEILING IN THE FOOD PREP AREA AROUND THE DISH MACHINE VENTILATION HOOD AND IN THE DRY STORAGE ROOM.  MANAGEMENT INSTRUCTED TO REPAIR ALL SOURCES OF WATER LEAKS. | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: 4-101.19  OBSERVED RUST ON THE WIRE STORAGE SHELVES IN THE PREP COOLER AND WALK-IN COOLER. MANAGEMENT INSTRUCTED TO REPAINT OR REPLACE THE RUSTED WIRE STORAGE SHELVES.  | 49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: 4-602.13  CLEAN THE INTERIOR OF THE PREP COOLERS AND FREEZER AND THE TOP OF THE DISH MACHINE.  | 52. SEWAGE & WASTE WATER PROPERLY DISPOSED - Comments: 5-403.12  OBSERVED STANDING WATER ON THE FLOOR AT THE COOK'S LINE AND IN THE DISHWASHING AREA. MANAGEMENT INSTRUCTED TO MAINTAIN THE FLOOR DRY. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: 6-201.15  OBSERVED CARDBOARD STORED FLAT ON THE GROUND BENEATH THE RUBBER MATS IN THE PREP AREA. MANAGEMENT INSTRUCTED TO REMOVE THE CARDBOARD FROM THE FLOOR. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: 6-501.12  CLEAN THE GREASE ON THE FLOOR OF THE FOOD PREP AREA UNDER THE COOKING EQUIPMENT AND PREP TABLES. CLEAN THE FLOOR IN THE DRY STORAGE ROOM. | 59. PREVIOUS PRIORITY FOUNDATION VIOLATION CORRECTED - Comments: 8-404.13(B)(3)  PREVIOUS PRIORITY FOUNDATION VIOLATION NOT CORRECTED FROM REPORT #2484659 ON 2/9/21:   60 - PREVIOUS CORE VIOLATIONS WERE NOT CORRECTED FROM REPORT #2359915 ON 2/5/20: 49 - MUST CLEAN FOOD DEBRIS BUILD UP FROM FRYER CABINET, WHEEL BASES OF ALL COOKING, STORING AND DISHWASHING EQUIPMENT.  55 - OBSERVED DIRTY WALL WITH EXCESSIVE FOOD SPLATTER BEHIND COOKING LINE, FOOD PREP AREA AND WALLS BEHIND DISHWASHING AREA THE COOKS LINE AND GAS STOVE. GREASE ON WALL FAN AT THE REAR KITCHEN. MUST CLEAN AND MAINTAIN ALL.  PRIORITY 7-42-090.  CITATION ISSUED.",
#   'latitude': '41.97592670619184',
#   'longitude': '-87.69904568571212',
#   'location': {'latitude': '-87.69904568571212',
#    'longitude': '41.97592670619184'}},
#  {'inspection_id': '2484934',
#   'dba_name': 'LA ESCUELITA',
#   'aka_name': 'LA ESCUELITA',
#   'license_': '2488235',
#   'facility_type': "Children's Services Facility",
#   'risk': 'Risk 1 (High)',
#   'address': '5400 W FULLERTON AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60639',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'License',
#   'results': 'Pass',
#   'violations': '36. THERMOMETERS PROVIDED & ACCURATE - Comments: VISIBLE AND WORKING THERMOMETER NEEDED AT THE MILK 2-DOOR REFRIGERATOR. MUST PROVIDE AND MAINTAIN. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED DIRT BUILD UP ON FLOOR DRAINS IN THE UTILITY ROOM. MUST CLEAN AND MAINTAIN. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED A FEW DAMAGED CEILING TILES ABOVE PRE-K CLASS ROOM AND ABOVE STORAGE SHELVING IN 2-6 YEARS OLD CLASSROOM. MUST REPAIR AND REPALCE | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: OBSERVED MISSING LIGHT BULBS IN IN THE UNISEX WASHROOMS MUST REPAIR/REPLACE AND PROVIDE ADEQUATE LIGHTING. | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: OBSERVED HEAVY DUST BUILD UP ON CEILING VENTILATION VENTS ISIDE WASHROOMS THROUGHOUT FACILITY. MUST CLEAN AND MAINTAIN. | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: OBSERVED INADEQUATE LIGHTING IN FOOD PREPARATION AREA. MUST PROVIDE ADEQUATE LIGHTHING AND MAINTAIN.',
#   'latitude': '41.9241535287086',
#   'longitude': '-87.76113266206144',
#   'location': {'latitude': '-87.76113266206144',
#    'longitude': '41.9241535287086'}},
#  {'inspection_id': '2484978',
#   'dba_name': "ELLIOTT'S SEAFOOD AND CHOP HOUSE GRILL",
#   'aka_name': "ELLIOTT'S SEAFOOD AND CHOP HOUSE GRILL",
#   'license_': '44501',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '6688-6690 N NORTHWEST HWY ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60631',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Non-Inspection',
#   'results': 'No Entry',
#   'latitude': '42.00245899044439',
#   'longitude': '-87.81587721099274',
#   'location': {'latitude': '-87.81587721099274',
#    'longitude': '42.00245899044439'}},
#  {'inspection_id': '2484943',
#   'dba_name': "KOKO'S MEDITERRANEAN GRILL",
#   'aka_name': "KOKO'S MEDITERRANEAN GRILL",
#   'license_': '2293013',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '1760 W CHICAGO AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60622',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Canvass Re-Inspection',
#   'results': 'Pass',
#   'latitude': '41.89610267284695',
#   'longitude': '-87.67211594992528',
#   'location': {'latitude': '-87.67211594992528',
#    'longitude': '41.89610267284695'}},
#  {'inspection_id': '2484949',
#   'dba_name': 'POPE JOHN PAUL CATHOLIC',
#   'aka_name': 'POPE JOHN PAUL CATHOLIC',
#   'license_': '2040668',
#   'facility_type': 'School',
#   'risk': 'Risk 1 (High)',
#   'address': '4325 S RICHMOND ST ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60632',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass w/ Conditions',
#   'violations': '1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOWLEDGE, AND PERFORMS DUTIES - Comments: PERSON IN CHARGE WITHOUT CITY OF CHICAGO CERTIFIED MANAGER CERTIFICATE. INSTD TO PROVIDE AND MAINTAIN ON SITE | 2. CITY OF CHICAGO FOOD SERVICE SANITATION CERTIFICATE - Comments: NO CITY OF CHICAGO CERTIFIED MANAGER ON DUTY WHILE HANDLING TCS FOODS (MILK, CHEESE PIZZA) NOR VALID CITY OF CHICAGO CERTIFICATE POSTED. INSTD TO PROVIDE AND MAINTAIN. CITATION ISSUED PRIORITY FOUNDATION 7-38-012. | 3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: MISSING EMPLOYEE HEALTH POLICY. INSTD TO PROVIDE AND MAINTAIN A VERFIABLE EMPLOYEE ACKNOWLEDGED HEALTH POLICY ON SITE. PRIORITY FOUNDATION 7-38-010 | 10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: SOAP DISPENSER AND PAPER TOWEL DISPENSER LOCATED ABOVE UTILITY SERVICE SINK. INSTD TO REMOVE. | 38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: REAR EXIT DOOR NEAR PREP AREA NOT PROTECTED/RODENT PROOF, BOTTOM OF DOOR RUSTED, APPROX 1/4 INCH GAP. INSTD TO REPAIR AND MAINTAIN DOOR TIGHT FITTING | 49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: INTERIOR BOTTOM OF MILK COOLER NOT CLEAN, DEBRIS. INSTD TO CLEAN AND MAINTAIN SAME | 53. TOILET FACILITIES: PROPERLY CONSTRUCTED, SUPPLIED, & CLEANED - Comments: MISSING COVERS FOR RECEPTACLES IN WOMENS TOILET ROOMS. INSTD TO PROVIDE COVERS AND MAINTAIN',
#   'latitude': '41.81472363423928',
#   'longitude': '-87.69794253337163',
#   'location': {'latitude': '-87.69794253337163',
#    'longitude': '41.81472363423928'}},
#  {'inspection_id': '2484969',
#   'dba_name': 'BABY BURRITOS',
#   'aka_name': 'BABY BURRITOS',
#   'license_': '2235054',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '8121 S PULASKI RD ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60652',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass',
#   'violations': '41. WIPING CLOTHS: PROPERLY USED & STORED - Comments: ALL WIPING CLOTHS WHEN NOT IN USE MUST BE STORED IN A CLEAN SANITIZING SOLUTION. MAINTAIN AT ALL TIMES.  | 49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: COOKING EQUIPMENT IN NEED OF CLEANING TO REMOVE ALL FOOD SPILLS  INSTRUCTED TO CLEAN AND MAINTAIN CLEAN.  | 53. TOILET FACILITIES: PROPERLY CONSTRUCTED, SUPPLIED, & CLEANED - Comments: TOILET ROOM RECEPTACLE MUST BE COVERED CORRECT AND MAINTAIN. ',
#   'latitude': '41.745191759341516',
#   'longitude': '-87.72162461388663',
#   'location': {'latitude': '-87.72162461388663',
#    'longitude': '41.745191759341516'}},
#  {'inspection_id': '2484963',
#   'dba_name': '65TH FOODS CORP',
#   'aka_name': '65TH FOODS CORP',
#   'license_': '2501239',
#   'facility_type': 'Grocery Store',
#   'risk': 'Risk 3 (Low)',
#   'address': '6458 S STONY ISLAND AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60637',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Complaint',
#   'results': 'Pass w/ Conditions',
#   'violations': '3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: NO EMPLOYEE HEALTH POLICY ON PREMISES AS REQUIRED; MUST PROVIDE.  INSTRUCTED THE PERSON IN CHARGE TO PROVIDE DOCUMENTATION OF EMPLOYEES RESPONSIBILITY TO REPORT ANY ILLNESS TRANSMISSIBLE THROUGH FOOD.  PRIORITY FOUNDATION VIOLATION 7-38-010. | 5. PROCEDURES FOR RESPONDING TO VOMITING AND DIARRHEAL EVENTS - Comments: NO VOMIT AND DIARRHEA CLEAN UP PROCEDURE ON PREMISES AS REQUIRED; MUST PROVIDE.  INSTRUCTED THE PERSON IN CHARGE THAT A VOMIT AND DIARRHEA CLEAN UP PROCEDURE MUST BE DOCUMENTED AND THE NECESSARY SUPPLIES ON HAND IN THE EVENT OF A VOMIT AND DIARRHEAL INCIDENT ON PREMISES.  PRIORITY FOUNDATION VIOLATION 7-38-005 ISSUED. | 39. CONTAMINATION PREVENTED DURING FOOD PREPARATION, STORAGE & DISPLAY - Comments: MUST INSTALL A SPLASH GUARD BETWEEN THE UTILITY SINK AND THE EXPOSED HANDSINK IN PREP AREA. | 51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICES - Comments: NO BACKFLOW PREVENTION DEVICE ON MOP SINK; INSTRUCTED TO INSTALL A BACKFLOW PREVENTION DEVICE.',
#   'latitude': '41.77706522667996',
#   'longitude': '-87.58648091591249',
#   'location': {'latitude': '-87.58648091591249',
#    'longitude': '41.77706522667996'}},
#  {'inspection_id': '2484922',
#   'dba_name': 'LEO HIGH SCHOOL',
#   'aka_name': 'LEO HIGH SCHOOL',
#   'license_': '2247637',
#   'facility_type': 'School',
#   'risk': 'Risk 1 (High)',
#   'address': '7901 S SANGAMON ST ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60620',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Fail',
#   'violations': '1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOWLEDGE, AND PERFORMS DUTIES - Comments: OBSERVED NO PERSON IN CHARGE WITH VALID CHICAGO FOOD SANITATION CERTIFICATE. INSTRUCTED MANAGER TO DESIGNATE PERSON IN CHARGE DURING ALL HOURS OF OPERATION. PRIORITY FOUNDATION  | 2. CITY OF CHICAGO FOOD SERVICE SANITATION CERTIFICATE - Comments: OBSERVED NO CERTIFIED MANAGER ON SITE OR VALID CHICAGO FOOD SANITATION CERTIFICATE POSTED WHEN TCS FOOD PREPARED AND SERVED. A CERTIFIED MANAGER MUST BE ON SITE AT ALL TIMES TCS FOOD IS PREPARED AND VALID CHICAGO FOOD SANITATION CERTIFICATE POSTED. PRIORITY FOUNDATION 7-38-012 CITATION ISSUED. | 38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: OBSERVED OVER 40 MICE DROPPINGS SCATTERED ON FLOOR AND SHELVES IN UTENSIL STORAGE AREA, 40 MICE DROPPINGS SCATTERED ON FLOOR ALONG WALLS AND CORNERS IN UNUSED WALK-IN COOLER, 20 MICE DROPPINGS SCATTERED ON FLOOR ALONG WALLS AND CORNES IN ELECTRICAL CLOSET IN SERVING AREA. INSTRUCTED MANAGER TO CALL AN EXTERMINATOR FOR SERVICE, CLEAN AND SANITIZE ALL AREAS. PRIORITY FOUNDATION 7-38-020(A) CITATION ISSUED. | 53. TOILET FACILITIES: PROPERLY CONSTRUCTED, SUPPLIED, & CLEANED - Comments: OBSERVED NO COVERED WASTE RECEPTACLE IN KITCHEN STAFF WASHROOM. INSTRUCTED MANAGER TO PROVIDE. | 54. GARBAGE & REFUSE PROPERLY DISPOSED; FACILITIES MAINTAINED - Comments: OBSERVED NO WASTE RECEPTACLE AT HAND WASHING SINKS IN PREP AND SERVING AREAS. INSTRUCTED MANAGER TO PROVIDE. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED CEILING LEAKING IN KITCHEN, PEELING PAINT ON CEILING AND UPPER WALLS IN KITCHEN, MISSING BASEBOARDS IN KITCHEN, OPENINGS AROUND PIPE FITTINGS IN KITCHEN, OPENINGS ALONG BASEBOARDS IN CAFETERIA. INSTRUCTED MANAGER TO REPAIR ALL LEAKS, REMOVE PEELING PAINT AND SEAL ALL OPENINGS ALONG WALLS, AROUND PIPE FITTINGS IN ALL AREAS. | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: OBSERVED NO LIGHT IN WALK-IN COOLER AND INADEQUATE LIGHTING IN KITCHEN STAFF WASHROOM. INSTRUCTED MANAGER TO PROVIDE ADEQUATE LIGHTING AND MAINTAIN. | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: OBSERVED MISSING LIGHT SHIELDS IN VENTILATION HOOD AND DISH WASHING AREAS. INSTRUCTED MANAGER TO PROVIDE LIGHT SHIELDS OR SHATTERPROOF BULBS.',
#   'latitude': '41.75058054137408',
#   'longitude': '-87.64753525162135',
#   'location': {'latitude': '-87.64753525162135',
#    'longitude': '41.75058054137408'}},
#  {'inspection_id': '2484988',
#   'dba_name': 'DAVIDsTEA',
#   'aka_name': 'DAVIDsTEA',
#   'license_': '2320714',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 2 (Medium)',
#   'address': '151 N MICHIGAN AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60601',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Out of Business',
#   'latitude': '41.88454011059238',
#   'longitude': '-87.62430852246028',
#   'location': {'latitude': '-87.62430852246028',
#    'longitude': '41.88454011059238'}},
#  {'inspection_id': '2484938',
#   'dba_name': 'J + L FAMILY LEARNING DAYCARE CENTER',
#   'aka_name': 'J + L FAMILY LEARNING DAYCARE CENTER',
#   'license_': '2220707',
#   'facility_type': 'Daycare Above and Under 2 Years',
#   'risk': 'Risk 1 (High)',
#   'address': '11638-11640 S WENTWORTH AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60628',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'License',
#   'results': 'Fail',
#   'violations': "1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOWLEDGE, AND PERFORMS DUTIES - Comments: SEE VIOLATION #2 | 2. CITY OF CHICAGO FOOD SERVICE SANITATION CERTIFICATE - Comments: OBSERVED NO VALID CITY OF CHICAGO FOOD SANITATION CERTIFICATE POSTED FOR PIC. INSTRUCTED FACILITY REQUIRED TO HAVE A VALID CITY OF CHICAGO FOOD SAN ITATION CERTIFICATE POSTED FOR PIC. PRIORITY FOUN DATION ISSUED 7-38-012 | 51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICES - Comments: OBSERVED HOT WATER FAUCET NOT MAINTAINED AT  CHILDREN'S 4TH HAND SINK,ON THE( RIGHT) OUTSIDE WASHROOM. INSTRUCTED TO REPAIR. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED PEELING PAINT ON WALL AREAS BY BED STORAGE AREA NEAR HAND SINKS. INSTRUCTED TO REPAIR.",
#   'latitude': '41.68225833336412',
#   'longitude': '-87.62773601885556',
#   'location': {'latitude': '-87.62773601885556',
#    'longitude': '41.68225833336412'}},
#  {'inspection_id': '2484976',
#   'dba_name': "BABA'S COFFEE",
#   'aka_name': "BABA'S COFFEE",
#   'license_': '2423353',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '5544-5546 N KEDZIE AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60625',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Fail',
#   'violations': '38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: OBSERVED NO PEST CONTROL LOG BOOK ON THE PREMISES.  MANAGEMENT INSTRUCTED TO HAVE A PEST CONTROL LOG BOOK FROM A LICENSED PEST CONTROL COMPANY WITH ALL  REQUIRED DOCUMENTS.  PRIORITY FOUNDATION 7-38-020(C).  NO CITATION ISSUED.',
#   'latitude': '41.98258181784537',
#   'longitude': '-87.70899575100229',
#   'location': {'latitude': '-87.70899575100229',
#    'longitude': '41.98258181784537'}},
#  {'inspection_id': '2484939',
#   'dba_name': "MARIA'S MEXICAN RESTURANT",
#   'aka_name': "MARIA'S MEXICAN RESTURANT",
#   'license_': '22926',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '9440 W FOSTER AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60656',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass w/ Conditions',
#   'violations': "3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: OBSERVED NO VERIFIABLE HEALTH POLICY ON SITE AT TIME OF INSPECTION. INSTRUCTED TO MAINTAIN COPIES OF HEALTH POLICY SIGNED BY ALL EMPLOYEES ON SITE AT ALL TIMES. PRIORITY FOUNDATION VIOLATION 7-38-010. NO CITATION ISSUED.  | 10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: OBSERVED NO HAND WASH SIGNAGE AT EXPOSED HAND SINK OPPOSITE DISH AREA. INSTRUCTED TO PROVIDE.  | 10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: OBSERVED NO HANDWASHING SIGNAGE AT WASHBOWL SINK LOCATED IN REAR EMPLOYEE WASHROOM. INSTRUCTED TO PROVIDE.  | 22. PROPER COLD HOLDING TEMPERATURES - Comments: OBSERVED MULTIPLE CONTAINERS OF SLICED BEEF INSIDE 3 DOOR REFRIGERATOR ON MAIN COOK LINE AT IMPROPER TEMPERATURES BETWEEN 54.3F AND 55.2F. MANAGEMENT VOLUNTARILY DISCARDED AND DENATURED APPROXIMATELY 10 LBS OF PRODUCT VALUED AT APPROXIMATEY $100. INSTRUCTED TO MAINTAIN ALL TCS FOODS AT OR BELOW 41F. PRIORITY VIOLATION 7-38-005. CITATION ISSUED.  | 25. CONSUMER ADVISORY PROVIDED FOR RAW/UNDERCOOKED FOOD - Comments: OBSERVED ITEMS ON MENU SERVED RAW OR UNDERCOOKED, SUCH AS CEVICHE, WITH NO DISCLOSURE, REMINDER, AND DISCLAIMER. INSTRUCTED TO PROVIDE DISCLOSURE, REMINDER, AND DISCLAIMER ON ALL VERSIONS OF MENU FOR ALL ITEMS SERVED RAW OR UNDERCOOKED. PRIORITY FOUNDATION VIOLATION 7-38-005. NO CITATION ISSUED.  | 33. PROPER COOLING METHODS USED; ADEQUATE EQUIPMENT FOR TEMPERATURE CONTROL - Comments: OBSERVED 3 DOOR REFRIGERATOR ON MAIN COOK LINE CONTAINING TCS FOODS SUCH AS SLICED BEEF MAINTAINING AN IMPROPER AMBIENT TEMPERATURE OF 53.1F. COOLER TAGGED AND HELD FOR INSPECTION. INSTRUCTED TO MAINTAIN ALL COOLERS AT OR BELOW 41F. PRIORITY VIOLATION 7-38-005. CITATION ISSUED.  | 37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER - Comments: OBSERVED BARRELS CONTAINING TORTILLA CHIPS WITH NO LABELS. INSTRUCTED TO LABEL ALL BARRELS WITH THE COMMON NAME OF THE PRODUCT.  | 51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICES - Comments: OBSERVED WASHBOWL SINK LOCATED IN EMPLOYEE TOILET ROOM COMING LOOSE FROM WALL. INSTRUCTED TO RECAULK AND SECURELY MOUNT TO WALL.  | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: OBSERVED HEAVY BUILD UP OF GREASE AND GRIME ON FILTERS ABOVE MAIN COOK LINE. INSTRUCTED TO CLEAN AND MAINTAIN.  | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: OBSERVED BUILD UP OF DUST ON FANS IN WALK-IN COOLER USED TO STORE PROTEINS. INSTRUCTED TO CLEAN AND MAINTAIN.  | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: OBSERVED HEAVY BUILD UP OF DUST ON FAN IN EMPLOYEE TOILET ROOM. INSTRUCTED TO CLEAN AND MAINTAIN.  | 60. PREVIOUS CORE VIOLATION CORRECTED - Comments: OBSERVED REPEAT CORE VIOLATION FROM REPORT #2286172 DATED 5/2/2019 NOT CORRECTED:'OBSERVED NO ALLERGEN CERTIFICATION ON SITE.INSTRUCTED MANAGEMENT TO BECOME ALLERGEN CERTIFIED. CORE VIOLATION' INSTRUCTED TO COME INTO COMPLIANCE. PRIORITY FOUNDATION VIOLATION 7-42-090. NO CITATION ISSUED. ",
#   'latitude': '41.973400958457454',
#   'longitude': '-87.86302998092812',
#   'location': {'latitude': '-87.86302998092812',
#    'longitude': '41.973400958457454'}},
#  {'inspection_id': '2484955',
#   'dba_name': 'HEXE COFFEE',
#   'aka_name': 'HEXE COFFEE',
#   'license_': '2653036',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 2 (Medium)',
#   'address': '2832 N CLYBOURN AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60618',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass w/ Conditions',
#   'violations': "2. CITY OF CHICAGO FOOD SERVICE SANITATION CERTIFICATE - Comments: OBSERVED FACILITY FOOD HANDLERS PREPARING AND HANDLING  TIME AND TEMPERATURE CONTROL FOR SAFETY(TCS) FOODS (SLICING DELI MEAT, DELI SANDWICHES) WITHOUT ORIGINAL CITY OF CHICAGO FOOD SERVICE MANAGER AND CERTIFICATE ON SITE. INFORMED PERSON IN CHARGE CITY OF CHICAGO ORIGINAL FOOD SERVICE CERTIFICATE MUST REMAIN POSTED ON SITE AND CERTIFIED MANAGER ON SITE DURING TCS FOOD PREP, COOKING, SERVING AND OPERATING HOURS. PRIORITY FOUNDATION VIOLATION #7-38-012. CITATION ISSUED. | 3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: OBSERVED NO WRITTEN EMPLOYEE HEALTH POLICY ON SITE. INSTRUCTED FACILITY TO ESTABLISH AN APPROPRIATE EMPLOYEE HEALTH POLICY AND MAINTAIN WITH VERIFIABLE SIGNED COPIES ON SITE FOR ALL FOOD EMPLOYEES.  PRIORITY FOUNDATION VIOLATION #7-38-010. NO CITATION ISSUED. | 40. PERSONAL CLEANLINESS - Comments: OBSERVED FOOD HANDLERS PREPPING FOOD WITHOUT HAIR RESTRAINTS. INSTRUCTED PERSON IN CHARGE THAT ALL FOOD HANDLERS MUST WEAR A HAIR RESTRAINT. | 48. WAREWASHING FACILITIES: INSTALLED, MAINTAINED & USED; TEST STRIPS - Comments: FACILITY USES HIGH TEMPERATURE SANITIZING DISH MACHINE AND DOESN'T HAVE PROPER TEMPERATURE MEASURING IRREVERSIBLE REGISTERING TEMPERATURE INDICATOR THAT SHALL BE PROVIDED AND READILY ACCESSIBLE FOR MEASURING THE UTENSIL SURFACE TEMPERATURE. INSTRUCTED TO PROVIDE. PRIORITY FOUNDATION VIOLATION 7-38-005 NO CITATION ISSUED.",
#   'latitude': '41.93276904780132',
#   'longitude': '-87.67901049486147',
#   'location': {'latitude': '-87.67901049486147',
#    'longitude': '41.93276904780132'}},
#  {'inspection_id': '2484972',
#   'dba_name': 'EL TACO SABROSO #1 INC',
#   'aka_name': 'EL TACO SABROSO #1 INC',
#   'license_': '2446376',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '8346 S PULASKI RD ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60652',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass',
#   'violations': '37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER - Comments: ALL BULK FOOD ITEMS MUST BE PROPERLY LABELED WITH PRODUCT NAME. CORRECT AND MAINTAIN AT ALL TIMES.  | 53. TOILET FACILITIES: PROPERLY CONSTRUCTED, SUPPLIED, & CLEANED - Comments: TOILET ROOM TRASH CAN IN NEED OF LID AT ALL TIMES. CORRECT AND MAINTAIN.  | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: FLOORS THROUGH OUT IN NEED OF CLEANING TO REMOVE ALL FOOD SPILLS AND BUILD UP. CLEAN AND MAINTAIN CLEAN. ',
#   'latitude': '41.74074622126893',
#   'longitude': '-87.72177863827976',
#   'location': {'latitude': '-87.72177863827976',
#    'longitude': '41.74074622126893'}},
#  {'inspection_id': '2484984',
#   'dba_name': 'Flight Club',
#   'aka_name': 'Flight Club',
#   'license_': '2542031',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '111 W Wacker DR ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60601',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Complaint',
#   'results': 'Pass',
#   'violations': "10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: WEAK HOT WATER PRESSURE AT REAR PREP AREA AND WOMENS' TOILET ROOM HAND WASH SINKS. INSTRUCTED TO PROVIDE UNDER CITY PRESSURE.",
#   'latitude': '41.886706842036986',
#   'longitude': '-87.63140795865142',
#   'location': {'latitude': '-87.63140795865142',
#    'longitude': '41.886706842036986'}},
#  {'inspection_id': '2484966',
#   'dba_name': 'J J FISH & CHICKEN',
#   'aka_name': 'J J FISH & CHICKEN',
#   'license_': '1144900',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 2 (Medium)',
#   'address': '201-209 E 43RD ST ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60653',
#   'inspection_date': '2021-02-19T00:00:00.000',
#   'inspection_type': 'Complaint',
#   'results': 'Pass',
# ...
#   'latitude': '41.96865863857789',
#   'longitude': '-87.77718488891698',
#   'location': {'latitude': '-87.77718488891698',
#    'longitude': '41.96865863857789'}},
#  {'inspection_id': '2492947',
#   'dba_name': 'JJ FISH STATE INC.',
#   'aka_name': 'JJ FISH',
#   'license_': '2754079',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 2 (Medium)',
#   'address': '47 W 79TH ST ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60620',
#   'inspection_date': '2021-03-16T00:00:00.000',
#   'inspection_type': 'Complaint',
#   'results': 'Pass w/ Conditions',
#   'violations': '3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: OBSERVED NO SIGNED EMPLOYEE HEALTH POLICY ON PREMISES. INFORMED MANAGER TO HAVE EMPLOYEES SIGN AND KEEP ON SITE AT ALL TIMES. PRIORITY FOUNDATION. 7-38-010. NO CITATION ISSUED. | 5. PROCEDURES FOR RESPONDING TO VOMITING AND DIARRHEAL EVENTS - Comments: OBSERVED NO PROCEDURES FOR VOMIT AND DIARRHEA NOR SUPPLIES FOR VOMIT AND DIARRHEA KIT (GLOVES, DISPOSABLE APRON, SANITIZER, ETC). INSTRUCTED MANAGER TO PROVIDE AND KEEP ON PREMISES AT ALL TIMES. PRIORITY FOUNDATION. 7-38-005. NO CITATION ISSUED. | 41. WIPING CLOTHS: PROPERLY USED & STORED - Comments: OBSERVED WIPING CLOTH IMPROPERLY STORED IN HANDWASH SINK IN FRONT PREP AREA AND ON PREP TABLE. INSTRUCTED TO STORE WIPING CLOTHS IN SANITIZING SOLUTION BETWEEN USE. | 53. TOILET FACILITIES: PROPERLY CONSTRUCTED, SUPPLIED, & CLEANED - Comments: MUST PROVIDE A GARBAGE CAN WITH LID IN UNISEX TOILET ROOM.INSTRUCTED TO PROVIDE AND MAINTAIN. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED MISSING FLOOR TILE IN REAR PREP AREA NEAR WALK IN FREEZER AND UTILITY SINK. INSTRUCTED MANAGER TO PROVIDE AND MAINTAIN. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED MISSING TILE FROM CEILING IN REAR PREP AREA NEAR WALK IN FREEZER. INSTRUCTED MANAGER TO PROVIDE AND MAINTAIN. | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: OBSERVED FLICKERING LIGHT BULB IN EMPLOYEE RESTROOM. INSTRUCTED MANAGER TO PROVIDE ADEQUATE LIGHTING AND MAINTAIN. ',
#   'latitude': '41.75082437907816',
#   'longitude': '-87.62654379362712',
#   'location': {'latitude': '-87.62654379362712',
#    'longitude': '41.75082437907816'}},
#  {'inspection_id': '2492943',
#   'dba_name': 'BENTO BOX AND ARTISAN CATERING',
#   'aka_name': 'BENTO BOX',
#   'license_': '2060206',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '2246 W ARMITAGE AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60647',
#   'inspection_date': '2021-03-16T00:00:00.000',
#   'inspection_type': 'Non-Inspection',
#   'results': 'No Entry',
#   'latitude': '41.91773476803251',
#   'longitude': '-87.68438612753275',
#   'location': {'latitude': '-87.68438612753275',
#    'longitude': '41.91773476803251'}},
#  {'inspection_id': '2492950',
#   'dba_name': 'HOST INTERNATIONAL INC-GOOSE ISLAND T3',
#   'aka_name': 'GOOSE ISLAND CHICAGO (T3/L10)',
#   'license_': '34154',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '11601 W TOUHY AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60666',
#   'inspection_date': '2021-03-16T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass',
#   'violations': '10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: INSTRUCTED TO PROVIDE HANDWASHING SIGNAGE AT HANDSINK BEHIND THE BAR (RIGHT SIDE). | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: INSTRUCTED TO REFINISH OR REPLACE (2) CUTTING BOARDS WITH STAIN AND DEEP SEAMS ON TOP OF PREP COOLERS IN PREP/COOKING AREA. | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: INSTRUCTED TO CLEAN AND REPAINT TOP COVER OF GREASE BOX WITH RUST ACCUMULATION  UNDERNEATH 3 COMPARTMENT SINK IN REAR DISHWASHING AREA. | 49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: INSTRUCTED TO DETAIL CLEAN AND MAINTAIN INTERIOR SURFACES OF 3 COMPARTMENT SINK IN REAR DISHWASHING AREA AND MUST CLEAN AND MAINTAIN TOP EXTERIOR SURFACES OF DISHMACHINE WITH DRIED FOOD DEBRIS AND CALCIUM BUILD UP IN REAR DISHWASHING AREA. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: INSTRUCTED TO DETAIL CLEAN AND MAINTAIN BOTTOM WALL BEHIND DISHMACHINE WITH EXCESSIVE GREASE ACCUMULATION. | 57. ALL FOOD EMPLOYEES HAVE FOOD HANDLER TRAINING - Comments: FOOD HANDLERS WITH EXPIRED FOOD HANDLER TRAINING CERTIFICATE.  INSTRUCTED TO PROVIDE CURRENT CERTIFICATE FOR EACH EMPLOYEE. ',
#   'latitude': '42.008536400868735',
#   'longitude': '-87.91442843927047',
#   'location': {'latitude': '-87.91442843927047',
#    'longitude': '42.008536400868735'}},
#  {'inspection_id': '2492977',
#   'dba_name': 'ST. BESS JERK',
#   'aka_name': 'ST. BESS JERK',
#   'license_': '2762123',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '5729 N NORTHWEST HWY ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60646',
#   'inspection_date': '2021-03-16T00:00:00.000',
#   'inspection_type': 'Complaint',
#   'results': 'Fail',
#   'violations': '3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: OBSERVED NO EMPLOYEE HEALTH POLICY ON SITE. INSTRUCTED TO PROVIDE VERIFICATION FOR EACH EMPLOYEE ON SITE AT ALL TIMES. PRIORITY FOUNDATION. 7-38-010. NO CITATION ISSUED.  | 21. PROPER HOT HOLDING TEMPERATURES - Comments: OBSERVED THE FOLLOWING TCS FOOD ITEMS AT IMPROPER HOT HOLDING TEMPERATURE IN HOT HOLDING UNIT. COOKED OXTAIL FOUND AT 62.1F, COOKED CHICKEN FOUND AT 110.1F AND COOKED JERK CHICKEN FOUND ON COUNTER AT 67.3F. INSTRUCTED MANAGER PROPER HOT HOLDING TEMPERATURE MUST BE AT 135.0F OR HIGHER. INSTRUCTED TO DISCARD AND DENATURE FOOD IMMEDIATELY. ALL FOOD WEIGHING APPROXIMATELY 100 LBS AT A COST OF $200.00. PRIORITY VIOLATION. 7-38-005. CITATION ISSUED.  | 36. THERMOMETERS PROVIDED & ACCURATE - Comments: OBSERVED NO METAL STEM THERMOMETER ON SITE DURING INSPECTION. INSTRUCTED TO PROVIDE AT ALL TIMES. PRIORITY FOUNDATION VIOLATION. 7-38-005. CITATION ISSUED. | 37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER - Comments: OBSERVED BUCKETS OF SEASONING IN REAR PREP AREA WITHOUT A LABEL. INSTRUCTED TO PROVIDE THE COMMON NAME ON CONTAINER TO PROPERLY IDENTIFY FOOD ITEM.  | 43. IN-USE UTENSILS: PROPERLY STORED - Comments: OBSERVED ICE SCOOP STORED IN ICE. INSTRUCTED TO STORE IN CLEAN CONTAINER WHEN NOT IN USE. | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: OBSERVED ESTABLISHMENT USING HOME DEPOT BUCKETS TO STORE SEASONING AND SAUCE. INSTRUCTED MANAGER TO USE FOOD GRADE CONTAINERS THAT ARE WASHABLE AND EASY TO CLEAN.  | 48. WAREWASHING FACILITIES: INSTALLED, MAINTAINED & USED; TEST STRIPS - Comments: OBSERVED NO CHEMICAL TEST KIT ON SITE DURING INSPECTION. INSTRUCTED TO PROVIDE A CHEMICAL TEST KIT ON SITE TO ACCURATELY MEASURE THE CONCENTRATION OF SANITIZING SOLUTION. PRIORITY FOUNDATION VIOLATION. 7-38-005. CITATION ISSUED. | 54. GARBAGE & REFUSE PROPERLY DISPOSED; FACILITIES MAINTAINED - Comments: OBSERVED OUTSIDE GARBAGE DUMPSTER OVERFLOWING WITH TRASH PREVENTING LID CLOSURE. INSTRUCTED MANAGER TO STORE ALL TRASH INSIDE OF RECEPTICLE TO PREVENT ANY INSECTS OR PESTS. PRIORITY FOUNDATION VIOLATION. 7-38-020(B). CITATION ISSUED. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED GREASE SPILLS ON FLOORS IN FRONT PREP AREA. MUST CLEAN AND MAINTAIN. | 57. ALL FOOD EMPLOYEES HAVE FOOD HANDLER TRAINING - Comments: OBSERVED NO FOOD HANDLER TRAINING FOR CURRENT EMPLOYEES. MUST PROVIDE. MANAGER STATED HE RECENTLY HIRED A NEW STAFF LESS THAN 30 DAYS AGO. | 60. PREVIOUS CORE VIOLATION CORRECTED - Comments: PREVIOUS CORE VIOLATION NOT CORRECTED FROM 12/24/2020, REPORT #2464099. #58- ALLERGEN TRAINING IS REQUIRED FOR ALL EMPLOYEES THAT HAVE A CITY OF CHICAGO FOOD SANITATION CERTIFICATE. INSTRUCTED TO COMPLETE TRAINING AND KEEP CERTIFICATE ON SITE. PRIORITY FOUNDATION. 7-42-090. NO CITATION ISSUED.',
#   'latitude': '41.98600113711187',
#   'longitude': '-87.78752792018707',
#   'location': {'latitude': '-87.78752792018707',
#    'longitude': '41.98600113711187'}},
#  {'inspection_id': '2492907',
#   'dba_name': 'WHIPPED & BEATEN CULINARY WORKS',
#   'aka_name': 'WHIPPED & BEATEN CULINARY WORKS',
#   'license_': '2776158',
#   'facility_type': 'COOKING SCHOOL',
#   'risk': 'Risk 3 (Low)',
#   'address': '3611-3617 N BROADWAY ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60613',
#   'inspection_date': '2021-03-16T00:00:00.000',
#   'inspection_type': 'License',
#   'results': 'Pass',
#   'latitude': '41.94773174730859',
#   'longitude': '-87.64734303203468',
#   'location': {'latitude': '-87.64734303203468',
#    'longitude': '41.94773174730859'}},
#  {'inspection_id': '2492934',
#   'dba_name': 'SMYSER ELEMENTARY SCHOOL',
#   'aka_name': 'SMYSER ELEMENTARY SCHOOL',
#   'license_': '25401',
#   'facility_type': 'School',
#   'risk': 'Risk 1 (High)',
#   'address': '4310 N Melvina ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60634',
#   'inspection_date': '2021-03-16T00:00:00.000',
#   'inspection_type': 'Canvass Re-Inspection',
#   'results': 'Pass',
#   'violations': '55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: 6-201.17--INSTRUCTED TO REPLACE WATER STAINED CEILING TILES IN KITCHEN ADJACENT TO THE 3-COMPARTMENT SINK AREA.',
#   'latitude': '41.95889036698026',
#   'longitude': '-87.78201198466297',
#   'location': {'latitude': '-87.78201198466297',
#    'longitude': '41.95889036698026'}},
#  {'inspection_id': '2492892',
#   'dba_name': 'DUNKIN DONUTS BASKIN ROBBINS',
#   'aka_name': 'DUNKIN DONUTS BASKIN ROBBINS',
#   'license_': '1272459',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 2 (Medium)',
#   'address': '500 W ROOSEVELT RD ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60607',
#   'inspection_date': '2021-03-16T00:00:00.000',
#   'inspection_type': 'Canvass Re-Inspection',
#   'results': 'Pass',
#   'violations': '37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER - Comments: 3-302.12 NOTED NO LABELS FOR BULK STORAGE CONTAINERS (SUGAR). INSTRUCTED PERSON IN CHARGE ALL BULK AND WORKING FOOD INGREDIENT CONTAINERS MUST BE LABELED WITH CONTENTS NAME. | 53. TOILET FACILITIES: PROPERLY CONSTRUCTED, SUPPLIED, & CLEANED - Comments: 5-501.17 OBSERVED NO COVERED RECEPTACLE (WASTE CAN) FOR PROPER DISPOSAL OF SANITARY NAPKINS IN 1 OF 2 UNISEX WASHROOMS. INSTRUCTED TO PROVIDE COVERED WASTE RECEPTACLE. | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: 6-304.11 NOTED VENT FAN IN UNISEX WASHROOM IN HALLWAY NOT FUNCTIONING. INSTRUCTED TO REPAIR',
#   'latitude': '41.867362692616666',
#   'longitude': '-87.63929319464197',
#   'location': {'latitude': '-87.63929319464197',
#    'longitude': '41.867362692616666'}},
#  {'inspection_id': '2492941',
#   'dba_name': 'SEE THRU CHINESE KITCHEN',
#   'aka_name': 'SEE THRU CHINESE KITCHEN',
#   'license_': '2663906',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '7118 S WESTERN AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60636',
#   'inspection_date': '2021-03-16T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass w/ Conditions',
#   'violations': '10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: OBSERVED AT INSPECTION EMPLOYEES HANDWASHING SINK NOT ACCESSIBLE FOR FOOD HANDLERS TO WASH HANDS,( IE LARGE METAL FOOD PAN STORED INSIDE OF HAND SINK). PIC REMOVED FOOD PAN-COS. INSTRUCTED PIC HANDWASHING SINK MUST ALWAYS BE ACCESSIBLE FOR USE,NOTHING INSIDE OR IN FRONT OF SINK. PRIORITY FOUNDATION ISSUED 7-38-030(C). | 49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: OBSERVED DRY STORAGE DISPLAY SHELVES NOT CLEAN OF DEBRIS. INSTRUCTED TO CLEAN/MAINTAIN.',
#   'latitude': '41.76409854092722',
#   'longitude': '-87.68337319418565',
#   'location': {'latitude': '-87.68337319418565',
#    'longitude': '41.76409854092722'}},
#  {'inspection_id': '2492904',
#   'dba_name': 'WINTHROP CHILDREN',
#   'aka_name': 'WNTHROP CHILDREN',
#   'license_': '2215541',
#   'facility_type': 'Daycare (2 - 6 Years)',
#   'risk': 'Risk 1 (High)',
#   'address': '4848 N WINTHROP AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60640',
#   'inspection_date': '2021-03-16T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Out of Business',
#   'latitude': '41.97048400251602',
#   'longitude': '-87.65780618896973',
#   'location': {'latitude': '-87.65780618896973',
#    'longitude': '41.97048400251602'}},
#  {'inspection_id': '2492948',
#   'dba_name': 'GHYNAROS GRILL',
#   'aka_name': 'GHYNAROS GRILL',
#   'license_': '2771450',
#   'risk': 'Risk 1 (High)',
#   'address': '3224 W FOSTER AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60625',
#   'inspection_date': '2021-03-16T00:00:00.000',
#   'inspection_type': 'License',
#   'results': 'Not Ready',
#   'latitude': '41.97584622052377',
#   'longitude': '-87.70968162978451',
#   'location': {'latitude': '-87.70968162978451',
#    'longitude': '41.97584622052377'}},
#  {'inspection_id': '2492927',
#   'dba_name': 'BASKIN ROBBINS/ DUNKIN DONUTS',
#   'aka_name': 'BASKIN ROBBINS/ DUNKIN DONUTS',
#   'license_': '45960',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 2 (Medium)',
#   'address': '3039 N CENTRAL AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60634',
#   'inspection_date': '2021-03-16T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Fail',
#   'violations': "38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: OBSERVED OPENING APPROX:1/4' AT BOTTOM CENTER BETWEEN FRONT ENTRANCE DOUBLE DOORS.MUST MAKE DOOR TIGHT FITTING TO PREVENT PEST ENTRY. | 49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: OBSERVED FAN COVER WITH ACCUMULATION OF DUSTS IN (DRIVE-THRU) REFRIGERATOR.MUST CLEAN IN DETAIL AND MAINTAIN. | 51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICES - Comments: OBSERVED WATER LEAK AT BASE OF FAUCET AT THE (BASKIN-ROBBINS) 3-COMPARTMENT SINK.MUST REPAIR PLUMBING LEAK AND MAINTAIN. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED DIRTY FLOOR DRAINS AT THE (BASKIN-ROBBINS PREP AREA).MUST CLEAN IN DETAIL AND MAINTAIN. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED WATER STAINED CEILING TILES NEAR THE WOMENS WASHROOM.MUST REPLACE AND MAINTAIN. | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: OBSERVED MECHANICAL VENTILATION IN WASHROOMS NOT WORKING.MUST REPAIR AND MAINTAIN ADEQUATE VENTILATION AT ALL TIMES. | 60. PREVIOUS CORE VIOLATION CORRECTED - Comments: PREVIOUS CORE VIOLATIONS NOT CORRECTED FROM INSPECTION REPORT#2357021 DATED:01/21/2020  #51--BACKFLOW PREVENTER DEVICE NOT LOCATED BEHIND ICE MACHINE. INSTRUCTED TO INSTALL SO THAT IT CAN BE LOCATED TO BE SERVICED AND MAINTAINED.\tApr 21, 2020  #55--INSTRUCTED TO DETAIL CLEAN AND MAINTAIN LIGHT SHIELDS WITH DUST AND DEAD BUGS ABOVE REAR DRY STORAGE AREA.\tApr 21, 2020  #55--INSTRUCTED TO DETAIL CLEAN FLOORS ALONG THE WALLS AND IN ALL CORNERS IN BASEMENT STORAGE AREA AND IN FIRST FLOOR FRONT/REAR PREP AREA. USABLE ITEMS (FOOD AND NON FOOD) MUST BE STORED 6' OFF THE FLOOR FOR EASY ACCESS ON CLEANING.\tApr 21, 2020  #55--CLEANING EQUIPMENT (MOPS, BROOMS ETC) MUST BE STORED OFF THE FLOOR IN THE BASEMENT STORAGE AREA.\tApr 21, 2020  #55--INSTRUCTED TO REMOVE UNNECESSARY ARTICLES AND UNUSED ITEMS IN BASEMENT STORAGE AREA TO PREVENT PEST HARBORAGE.\tApr 21, 2020  INSTRUCTED TO CORRECT NOTED VIOLATIONS AND MAINTAIN BY 3/23/2021. PRIORITY FOUNDATION VIOLATION 7-42-090,NO CITATION ISSUED.",
#   'latitude': '41.93602793813531',
#   'longitude': '-87.76626204640748',
#   'location': {'latitude': '-87.76626204640748',
#    'longitude': '41.93602793813531'}}]

# %% [raw]
# pickle.loads(response["Body"].read())

# %% [raw]
# from io import BytesIO
# import pickle
#
# pickle.load(BytesIO(body))

# %% [raw]
# import cPickle
# cPickle.loads(body)

# %% [markdown]
# #### Creating bucket

# %%
bucket_name = "comdline-test-bucket-rob"

s3.create_bucket(
    Bucket=bucket_name,
    CreateBucketConfiguration={'LocationConstraint': 'us-west-2'},
    ACL="private"
)
# Out:
# {'ResponseMetadata': {'RequestId': 'C3D49DWEQ321XZ1W',
#   'HostId': 'IScnbV3aGQc8F+esmQVlkA7KlCOaJF0nfhRbyrYsTGjfjf/6L4x4xIEwVzpeLQa21ihbVNblyW8=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'IScnbV3aGQc8F+esmQVlkA7KlCOaJF0nfhRbyrYsTGjfjf/6L4x4xIEwVzpeLQa21ihbVNblyW8=',
#    'x-amz-request-id': 'C3D49DWEQ321XZ1W',
#    'date': 'Sun, 18 Apr 2021 15:14:12 GMT',
#    'location': 'http://comdline-test-bucket-rob.s3.amazonaws.com/',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'Location': 'http://comdline-test-bucket-rob.s3.amazonaws.com/'}

# %% [markdown]
# #### Uploading file to bucket

# %%
file_to_upload = "../../admin/test_file3_for_s3.txt"
file_name = file_to_upload.split(sep="/")[-1]

# %%
# s3.upload_file(file_to_upload, bucket_name, file_name)

s3.meta.client.upload_file(file_to_upload, bucket_name, file_name)

# %%
[obj for obj in s3.Bucket(bucket_name).objects.all()]

# %% [markdown]
# #### Downloading files from bucket

# %%
path_to_download = "/Users/rp_mbp/Documents/ReposRob_RobPer/ITAMmcd/semestre_2/Arquitectura_Prod_Dat/Venv_ArqPD/repos/dpa_2021/_robdir/" + file_name

s3.meta.client.download_file(bucket_name, file_name, path_to_download)

# %% [markdown]
# #### Deleting bucket files

# %%
s3.Object(bucket_name, file_name).delete()

# %% [markdown]
# ---

# %% [markdown]
# #### Deleting bucket

# %% [markdown]
# ## Downloading and storing Chicago data

# %% [markdown]
# #### Interacting with API

# %%
dataset_id = "4ijn-s7e5"

# %%
token = get_api_token("../conf/local/credentials.yaml")
token
# Out:
# '5HfsId12lhMMzSlYANoAq451w'

# %%
client = get_client(token)
client

# %% [raw]
# y = client.get_all(dataset_id)

# %%
most_rec_date = '2021-04-10'

# %%
soql_query = "inspection_date >= '{}'".format(most_rec_date)
soql_query
# Out:
# "inspection_date >= '2021-04-10'"

# %%
x = client.get(dataset_id, 
               limit=10,
               where=soql_query
              )

# %%
x
# Out:
# [{'inspection_id': '2498114',
#   'dba_name': 'CELTIC CROWN',
#   'aka_name': 'CELTIC CROWN',
#   'license_': '404',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '4301 N WESTERN AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60618',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Non-Inspection',
#   'results': 'No Entry',
#   'latitude': '41.959539275814876',
#   'longitude': '-87.68848380383307',
#   'location': {'latitude': '-87.68848380383307',
#    'longitude': '41.959539275814876'}},
#  {'inspection_id': '2498106',
#   'dba_name': 'ASIAN CUISINE EXPRESS',
#   'aka_name': 'ASIAN CUISINE EXPRESS',
#   'license_': '2327198',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '3823 W 31ST ST ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60623',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass',
#   'latitude': '41.836838656288656',
#   'longitude': '-87.72053342728425',
#   'location': {'latitude': '-87.72053342728425',
#    'longitude': '41.836838656288656'}},
#  {'inspection_id': '2498093',
#   'dba_name': 'CHAPPELL SCHOOL',
#   'aka_name': 'CHAPPELL SCHOOL',
#   'license_': '22681',
#   'facility_type': 'School',
#   'risk': 'Risk 1 (High)',
#   'address': '2135 W Foster AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60625',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Canvass Re-Inspection',
#   'results': 'Fail',
#   'violations': "10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: 5-202.12(A)  OBSERVED NO HOT WATER PROVIDED AT THE HAND WASHING SINK IN THE 2ND FLOOR GIRLS' WASHROOM IN THE NEW BUILDING.  THE WATER TEMPERATURE AT THE HAND WASHING SINK WAS AT 58F.  MANAGEMENT INSTRUCTED TO PROVIDE HOT WATER ABOVE 100F AT ALL HAND WASHING SINKS.  PRIORITY 7-38-030(C). | 38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: 6-501.111  OBSERVED EVIDENCE OF PEST ACTIVITY IN THE CLASSROOMS.  OBSERVED 10 MOUSE DROPPINGS IN THE BOTTOM SHELF OF THE WOODEN ART CABINET IN ROOM 107. MANAGEMENT INSTRUCTED TO CLEAN AND REMOVE ALL RODENT DROPPINGS FROM ALL AFFECTED AREAS. ADDITIONAL PEST CONTROL SERVICE IS NEEDED TO ELIMINATE THE PEST ACTIVITY FROM THE BUILDING. PRIORITY FOUNDATION 7-38-020(A).",
#   'latitude': '41.97586700298142',
#   'longitude': '-87.68325437820378',
#   'location': {'latitude': '-87.68325437820378',
#    'longitude': '41.97586700298142'}},
#  {'inspection_id': '2498087',
#   'dba_name': 'CARL VON LINNE ELEMENTARY SCHOOL',
#   'aka_name': 'CARL VON LINNE ELEMENTARY SCHOOL',
#   'license_': '24201',
#   'facility_type': 'School',
#   'risk': 'Risk 1 (High)',
#   'address': '3221 N SACRAMENTO BLVD ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60618',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Fail',
#   'violations': "10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: OBSERVED HANDSINK IN SHARED TOILET ROOM PRE-K CLASSROOM #128 AND #130  NOT STOCKED WITH HAND SOAP. INFORMED PERSON IN CHARGE THAT HAND SOAP MUST BE AVAILABLE AT HANDSINKS AT ALL TIMES. THE TEACHER OBTAINED HAND SOAP FOR HAND SINK DURING TIME OF INSPECTION. PRIORITY FOUNDATION VIOLATION #7-38-030(C). NO CITATION ISSUED. | 38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: OBSERVED NO CURRENT PEST CONTROL LOG BOOK ON THE PREMISES. INSTRUCTED PERSON IN CHARGE THAT A LICENSED PEST CONTROL COMPANY AND OPERATOR MUST PROVIDE AT LEAST 2 PEST INSPECTIONS A YEAR AND THE REPORTS MUST BE MAINTAINED IN THE LOG BOOK. INSTRUCTED TO PROVIDE A CURRENT PEST CONTROL LOG BOOK AND PEST INSPECTION REPORT.  PRIORITY FOUNDATION 7-38-020(C). NO CITATION ISSUED. | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: OBSERVED RUSTY SHELVES IN THE WALK-IN COOLER. MUST BE SMOOTH, AND EASILY CLEANABLE SURFACES. | 51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICES - Comments: OBSERVED THE TWO FAUCET HANDLES AT THE HAND SINK IN THE TEACHER'S LOUNGE TO HAVE A LEAK. INSTRUCTED TO REPAIR.",
#   'latitude': '41.94001885475702',
#   'longitude': '-87.70259824915517',
#   'location': {'latitude': '-87.70259824915517',
#    'longitude': '41.94001885475702'}},
#  {'inspection_id': '2498082',
#   'dba_name': 'THE BREWERY',
#   'aka_name': 'THE BREWERY',
#   'license_': '2551384',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '3848 N HARLEM AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60634',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Non-Inspection',
#   'results': 'No Entry',
#   'latitude': '41.95034769269968',
#   'longitude': '-87.80732944580947',
#   'location': {'latitude': '-87.80732944580947',
#    'longitude': '41.95034769269968'}},
#  {'inspection_id': '2498132',
#   'dba_name': 'JAYAKA CORPORATION',
#   'aka_name': 'MR. SUBMARINE',
#   'license_': '2781330',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '47 N WELLS ST ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60606',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'License',
#   'results': 'Pass',
#   'violations': '36. THERMOMETERS PROVIDED & ACCURATE - Comments: MISSING AND INACCURATE THERMOMOETR FOR WALK-IN AND PREP COOLERS, INSTRUCTED TO INSTALL. | 44. UTENSILS, EQUIPMENT & LINENS: PROPERLY STORED, DRIED, & HANDLED - Comments: UTENSILS NOT PROPERLY AIR DRIED, INSTRUCTED MANAGER TO AIR DRY ALL MULTI-USE UENSILS AFTER WASHING. | 45. SINGLE-USE/SINGLE-SERVICE ARTICLES: PROPERLY STORED & USED - Comments: USING NOT FOOD GRADE CONTAINERS WITH CHIPPED EDGES, INSTURED TO USE DURABLE FOOD GRADE CONTAINERS. | 51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICES - Comments: UNABLE TO LOCATE BACKFLOW PREVENTION DEVICE FOR ICE MAKER IN BASEMENT. INSTRUCTED TO INSTALL. | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: MISSING LIGHT SHIELDS FOR CEILING FIXTURE OF BASEMENT PREP AREA. INSTRUCTED TO INSTALL.',
#   'latitude': '41.883131152793595',
#   'longitude': '-87.63371346963126',
#   'location': {'latitude': '-87.63371346963126',
#    'longitude': '41.883131152793595'}},
#  {'inspection_id': '2498123',
#   'dba_name': 'CHIPOTLE MEXICAN GRILL',
#   'aka_name': 'CHIPOTLE MEXICAN GRILL',
#   'license_': '2109272',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '2809 N ASHLAND AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60657',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass',
#   'latitude': '41.93270303163393',
#   'longitude': '-87.66825941420389',
#   'location': {'latitude': '-87.66825941420389',
#    'longitude': '41.93270303163393'}},
#  {'inspection_id': '2498105',
#   'dba_name': 'BAR CAFE SAN FRANCESCO',
#   'aka_name': 'BAR CAFE SAN FRANCESCO',
#   'license_': '17161',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '3815 N HARLEM AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60634',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass',
#   'violations': "10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: INSTRUCTED TO PROVIDE AND MAINTAIN HANDWASHING SIGNAGE AT ALL HANDSINKS(BAR,WASHROOM). | 38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: OBSERVED FRONT SCREEN DOOR WITH GAP APPROXIMATELY 1/4' INCH OPENING AT BOTTOM LEFT CORNER.MUST MAKE DOOR TIGHT FITTING ALL ACROSS THE BOTTOM TO PREVENT PEST ENTRY. | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: INSTRUCTED NOT TO USE GROCERY BAGS FOR FOOD STORAGE INSIDE REFRIGERATION UNITS. MUST USE FOOD GRADE STORAGE BAGS OR CONTAINERS.  | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: OBSERVED MISSING SINK STOPPERS FOR THE BAR 3-COMPARTMENT SINK.INSTRUCTED TO PROVIDE AND MAINTAIN 3 ADEQUATE WORKING SINK STOPPERS.  | 49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: INSTRUCTED TO DETAIL CLEAN AND MAINTAIN THE FOLLOWING: INTERIOR AND EXTERIOR SURFACES OF ALL COOLERS AND FREEZERS,PREP TABLES,STORAGE AND PREP SHELVES, INTERIOR AND EXTERIOR SURFACES OF 3-COMPARTMENT SINK.  | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: INSTRUCTED TO DETAIL CLEAN AND MAINTAIN FLOORS WITH FOOD DEBRIS AND SOME LITTER ALONG THE WALLS AND IN ALL CORNERS THROUGHOUT REAR KITCHEN PREP AREA AND IN THE FRONT BAR AREA.  | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: INSTRUCTED TO DETAIL CLEAN AND ORGANIZE KITCHEN PREP AREA AND FRONT BAR AREA AND REMOVE UNNECESSARY ARTICLES DUE TO POTENTIAL PEST HARBORAGE AND ELEVATE STOCK ITEMS OFF THE FLOOR AT LEAST 6' INCHES (MUST NOT USE MILK CRATES OR SODA CRATES FOR ELEVATING OF ITEMS).  | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: INSTRUCTED TO REMOVE ACCUMULATION OF DUSTS ON VENTILATION COVER IN WASHROOMS.",
#   'latitude': '41.94938961660852',
#   'longitude': '-87.80700291252472',
#   'location': {'latitude': '-87.80700291252472',
#    'longitude': '41.94938961660852'}},
#  {'inspection_id': '2498081',
#   'dba_name': 'HOUSE OF KIDS DAYCARE',
#   'aka_name': 'HOUSE OF KIDS',
#   'license_': '2215884',
#   'facility_type': "Children's Services Facility",
#   'risk': 'Risk 1 (High)',
#   'address': '7158 W ADDISON ST ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60634',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass',
#   'violations': '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: OBSERVED ALUMINUM FOIL LINERS ON KITCHEN COOKING STOVE.MUST REMOVE ALUMINUM FOIL LINERS AND MAINTAIN TO SMOOTH,EASILY CLEANABLE SURFACES. | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: OBSERVED BURNT-OUT LIGHT BULBS IN STUDENTS WASHROOM AND AT FRONT OFFICE AREA.MUST PROVIDE AND MAINTAIN ADEQUATE LIGHTING AT ALL TIMES.',
#   'latitude': '41.94539701438075',
#   'longitude': '-87.80571712400827',
#   'location': {'latitude': '-87.80571712400827',
#    'longitude': '41.94539701438075'}},
#  {'inspection_id': '2498086',
#   'dba_name': 'ELSIETECATERING',
#   'aka_name': 'ELSIETECATERING',
#   'license_': '2663526',
#   'facility_type': 'Catering',
#   'risk': 'Risk 1 (High)',
#   'address': '3817 S KEDZIE AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60632',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass',
#   'violations': '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: RAW WOOD STORAGE SHELVES ON SITE. INSTD TO SEAL/PAINT SAME SO AS BE A NON POROUS, EASILY CLEANABLE SURFACE | 53. TOILET FACILITIES: PROPERLY CONSTRUCTED, SUPPLIED, & CLEANED - Comments: MISSING COVER FOR RECEPTACLES IN TOILET. INSTD TO PROVIDE COVERS AND MAINTAIN',
#   'latitude': '41.82381861968802',
#   'longitude': '-87.70428542093514',
#   'location': {'latitude': '-87.70428542093514',
#    'longitude': '41.82381861968802'}}]

# %% [markdown]
# ##### Using "dumps"

# %%
xx = pickle.dumps(x)

# %%
xx

# %%
pickle.loads(xx)

# %% [markdown]
# ##### Using "dump"

# %%
pkl_store_loc = !pwd
pkl_store_loc = pkl_store_loc[0] + "/prueba_pickle.pkl"

# %%
pkl_store_loc
# Out:
# '/Users/rp_mbp/Documents/ReposRob_RobPer/ITAMmcd/semestre_2/Arquitectura_Prod_Dat/Venv_ArqPD/repos/dpa_2021/_robdir/prueba_pickle.pkl'

# %%
pickle.dump(x, open(pkl_store_loc, 'wb'))

# %%
pickle.load(open(pkl_store_loc, "rb"))
# Out:
# [{'inspection_id': '2498114',
#   'dba_name': 'CELTIC CROWN',
#   'aka_name': 'CELTIC CROWN',
#   'license_': '404',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '4301 N WESTERN AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60618',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Non-Inspection',
#   'results': 'No Entry',
#   'latitude': '41.959539275814876',
#   'longitude': '-87.68848380383307',
#   'location': {'latitude': '-87.68848380383307',
#    'longitude': '41.959539275814876'}},
#  {'inspection_id': '2498106',
#   'dba_name': 'ASIAN CUISINE EXPRESS',
#   'aka_name': 'ASIAN CUISINE EXPRESS',
#   'license_': '2327198',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '3823 W 31ST ST ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60623',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass',
#   'latitude': '41.836838656288656',
#   'longitude': '-87.72053342728425',
#   'location': {'latitude': '-87.72053342728425',
#    'longitude': '41.836838656288656'}},
#  {'inspection_id': '2498093',
#   'dba_name': 'CHAPPELL SCHOOL',
#   'aka_name': 'CHAPPELL SCHOOL',
#   'license_': '22681',
#   'facility_type': 'School',
#   'risk': 'Risk 1 (High)',
#   'address': '2135 W Foster AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60625',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Canvass Re-Inspection',
#   'results': 'Fail',
#   'violations': "10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: 5-202.12(A)  OBSERVED NO HOT WATER PROVIDED AT THE HAND WASHING SINK IN THE 2ND FLOOR GIRLS' WASHROOM IN THE NEW BUILDING.  THE WATER TEMPERATURE AT THE HAND WASHING SINK WAS AT 58F.  MANAGEMENT INSTRUCTED TO PROVIDE HOT WATER ABOVE 100F AT ALL HAND WASHING SINKS.  PRIORITY 7-38-030(C). | 38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: 6-501.111  OBSERVED EVIDENCE OF PEST ACTIVITY IN THE CLASSROOMS.  OBSERVED 10 MOUSE DROPPINGS IN THE BOTTOM SHELF OF THE WOODEN ART CABINET IN ROOM 107. MANAGEMENT INSTRUCTED TO CLEAN AND REMOVE ALL RODENT DROPPINGS FROM ALL AFFECTED AREAS. ADDITIONAL PEST CONTROL SERVICE IS NEEDED TO ELIMINATE THE PEST ACTIVITY FROM THE BUILDING. PRIORITY FOUNDATION 7-38-020(A).",
#   'latitude': '41.97586700298142',
#   'longitude': '-87.68325437820378',
#   'location': {'latitude': '-87.68325437820378',
#    'longitude': '41.97586700298142'}},
#  {'inspection_id': '2498087',
#   'dba_name': 'CARL VON LINNE ELEMENTARY SCHOOL',
#   'aka_name': 'CARL VON LINNE ELEMENTARY SCHOOL',
#   'license_': '24201',
#   'facility_type': 'School',
#   'risk': 'Risk 1 (High)',
#   'address': '3221 N SACRAMENTO BLVD ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60618',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Fail',
#   'violations': "10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: OBSERVED HANDSINK IN SHARED TOILET ROOM PRE-K CLASSROOM #128 AND #130  NOT STOCKED WITH HAND SOAP. INFORMED PERSON IN CHARGE THAT HAND SOAP MUST BE AVAILABLE AT HANDSINKS AT ALL TIMES. THE TEACHER OBTAINED HAND SOAP FOR HAND SINK DURING TIME OF INSPECTION. PRIORITY FOUNDATION VIOLATION #7-38-030(C). NO CITATION ISSUED. | 38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: OBSERVED NO CURRENT PEST CONTROL LOG BOOK ON THE PREMISES. INSTRUCTED PERSON IN CHARGE THAT A LICENSED PEST CONTROL COMPANY AND OPERATOR MUST PROVIDE AT LEAST 2 PEST INSPECTIONS A YEAR AND THE REPORTS MUST BE MAINTAINED IN THE LOG BOOK. INSTRUCTED TO PROVIDE A CURRENT PEST CONTROL LOG BOOK AND PEST INSPECTION REPORT.  PRIORITY FOUNDATION 7-38-020(C). NO CITATION ISSUED. | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: OBSERVED RUSTY SHELVES IN THE WALK-IN COOLER. MUST BE SMOOTH, AND EASILY CLEANABLE SURFACES. | 51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICES - Comments: OBSERVED THE TWO FAUCET HANDLES AT THE HAND SINK IN THE TEACHER'S LOUNGE TO HAVE A LEAK. INSTRUCTED TO REPAIR.",
#   'latitude': '41.94001885475702',
#   'longitude': '-87.70259824915517',
#   'location': {'latitude': '-87.70259824915517',
#    'longitude': '41.94001885475702'}},
#  {'inspection_id': '2498082',
#   'dba_name': 'THE BREWERY',
#   'aka_name': 'THE BREWERY',
#   'license_': '2551384',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '3848 N HARLEM AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60634',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Non-Inspection',
#   'results': 'No Entry',
#   'latitude': '41.95034769269968',
#   'longitude': '-87.80732944580947',
#   'location': {'latitude': '-87.80732944580947',
#    'longitude': '41.95034769269968'}},
#  {'inspection_id': '2498132',
#   'dba_name': 'JAYAKA CORPORATION',
#   'aka_name': 'MR. SUBMARINE',
#   'license_': '2781330',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '47 N WELLS ST ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60606',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'License',
#   'results': 'Pass',
#   'violations': '36. THERMOMETERS PROVIDED & ACCURATE - Comments: MISSING AND INACCURATE THERMOMOETR FOR WALK-IN AND PREP COOLERS, INSTRUCTED TO INSTALL. | 44. UTENSILS, EQUIPMENT & LINENS: PROPERLY STORED, DRIED, & HANDLED - Comments: UTENSILS NOT PROPERLY AIR DRIED, INSTRUCTED MANAGER TO AIR DRY ALL MULTI-USE UENSILS AFTER WASHING. | 45. SINGLE-USE/SINGLE-SERVICE ARTICLES: PROPERLY STORED & USED - Comments: USING NOT FOOD GRADE CONTAINERS WITH CHIPPED EDGES, INSTURED TO USE DURABLE FOOD GRADE CONTAINERS. | 51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICES - Comments: UNABLE TO LOCATE BACKFLOW PREVENTION DEVICE FOR ICE MAKER IN BASEMENT. INSTRUCTED TO INSTALL. | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: MISSING LIGHT SHIELDS FOR CEILING FIXTURE OF BASEMENT PREP AREA. INSTRUCTED TO INSTALL.',
#   'latitude': '41.883131152793595',
#   'longitude': '-87.63371346963126',
#   'location': {'latitude': '-87.63371346963126',
#    'longitude': '41.883131152793595'}},
#  {'inspection_id': '2498123',
#   'dba_name': 'CHIPOTLE MEXICAN GRILL',
#   'aka_name': 'CHIPOTLE MEXICAN GRILL',
#   'license_': '2109272',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '2809 N ASHLAND AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60657',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass',
#   'latitude': '41.93270303163393',
#   'longitude': '-87.66825941420389',
#   'location': {'latitude': '-87.66825941420389',
#    'longitude': '41.93270303163393'}},
#  {'inspection_id': '2498105',
#   'dba_name': 'BAR CAFE SAN FRANCESCO',
#   'aka_name': 'BAR CAFE SAN FRANCESCO',
#   'license_': '17161',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '3815 N HARLEM AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60634',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass',
#   'violations': "10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: INSTRUCTED TO PROVIDE AND MAINTAIN HANDWASHING SIGNAGE AT ALL HANDSINKS(BAR,WASHROOM). | 38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: OBSERVED FRONT SCREEN DOOR WITH GAP APPROXIMATELY 1/4' INCH OPENING AT BOTTOM LEFT CORNER.MUST MAKE DOOR TIGHT FITTING ALL ACROSS THE BOTTOM TO PREVENT PEST ENTRY. | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: INSTRUCTED NOT TO USE GROCERY BAGS FOR FOOD STORAGE INSIDE REFRIGERATION UNITS. MUST USE FOOD GRADE STORAGE BAGS OR CONTAINERS.  | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: OBSERVED MISSING SINK STOPPERS FOR THE BAR 3-COMPARTMENT SINK.INSTRUCTED TO PROVIDE AND MAINTAIN 3 ADEQUATE WORKING SINK STOPPERS.  | 49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: INSTRUCTED TO DETAIL CLEAN AND MAINTAIN THE FOLLOWING: INTERIOR AND EXTERIOR SURFACES OF ALL COOLERS AND FREEZERS,PREP TABLES,STORAGE AND PREP SHELVES, INTERIOR AND EXTERIOR SURFACES OF 3-COMPARTMENT SINK.  | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: INSTRUCTED TO DETAIL CLEAN AND MAINTAIN FLOORS WITH FOOD DEBRIS AND SOME LITTER ALONG THE WALLS AND IN ALL CORNERS THROUGHOUT REAR KITCHEN PREP AREA AND IN THE FRONT BAR AREA.  | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: INSTRUCTED TO DETAIL CLEAN AND ORGANIZE KITCHEN PREP AREA AND FRONT BAR AREA AND REMOVE UNNECESSARY ARTICLES DUE TO POTENTIAL PEST HARBORAGE AND ELEVATE STOCK ITEMS OFF THE FLOOR AT LEAST 6' INCHES (MUST NOT USE MILK CRATES OR SODA CRATES FOR ELEVATING OF ITEMS).  | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: INSTRUCTED TO REMOVE ACCUMULATION OF DUSTS ON VENTILATION COVER IN WASHROOMS.",
#   'latitude': '41.94938961660852',
#   'longitude': '-87.80700291252472',
#   'location': {'latitude': '-87.80700291252472',
#    'longitude': '41.94938961660852'}},
#  {'inspection_id': '2498081',
#   'dba_name': 'HOUSE OF KIDS DAYCARE',
#   'aka_name': 'HOUSE OF KIDS',
#   'license_': '2215884',
#   'facility_type': "Children's Services Facility",
#   'risk': 'Risk 1 (High)',
#   'address': '7158 W ADDISON ST ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60634',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass',
#   'violations': '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: OBSERVED ALUMINUM FOIL LINERS ON KITCHEN COOKING STOVE.MUST REMOVE ALUMINUM FOIL LINERS AND MAINTAIN TO SMOOTH,EASILY CLEANABLE SURFACES. | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: OBSERVED BURNT-OUT LIGHT BULBS IN STUDENTS WASHROOM AND AT FRONT OFFICE AREA.MUST PROVIDE AND MAINTAIN ADEQUATE LIGHTING AT ALL TIMES.',
#   'latitude': '41.94539701438075',
#   'longitude': '-87.80571712400827',
#   'location': {'latitude': '-87.80571712400827',
#    'longitude': '41.94539701438075'}},
#  {'inspection_id': '2498086',
#   'dba_name': 'ELSIETECATERING',
#   'aka_name': 'ELSIETECATERING',
#   'license_': '2663526',
#   'facility_type': 'Catering',
#   'risk': 'Risk 1 (High)',
#   'address': '3817 S KEDZIE AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60632',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass',
#   'violations': '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: RAW WOOD STORAGE SHELVES ON SITE. INSTD TO SEAL/PAINT SAME SO AS BE A NON POROUS, EASILY CLEANABLE SURFACE | 53. TOILET FACILITIES: PROPERLY CONSTRUCTED, SUPPLIED, & CLEANED - Comments: MISSING COVER FOR RECEPTACLES IN TOILET. INSTD TO PROVIDE COVERS AND MAINTAIN',
#   'latitude': '41.82381861968802',
#   'longitude': '-87.70428542093514',
#   'location': {'latitude': '-87.70428542093514',
#    'longitude': '41.82381861968802'}}]

# %% [markdown]
# ##### Storing data in S3

# %%
pkl_store_loc = !pwd
pkl_store_loc = pkl_store_loc[0] + "/prueba_pickle.pkl"
pkl_store_loc
# Out:
# '/Users/rp_mbp/Documents/ReposRob_RobPer/ITAMmcd/semestre_2/Arquitectura_Prod_Dat/Venv_ArqPD/repos/dpa_2021/_robdir/prueba_pickle.pkl'

# %%
## Storing file locally
pickle.dump(x, open(pkl_store_loc, "wb"))

# %%
## Loading file from local and saving as variable
xx = pickle.dumps(pickle.load(open(pkl_store_loc, "rb")))

# %%
## Saving pickle in s3
s3.put_object(
    Bucket=bucket_name,
    Key="test_pickle.pkl",
    Body=xx
)
# Out:
# {'ResponseMetadata': {'RequestId': '9XXVB722VK42KZJN',
#   'HostId': '00tEbVt/wGh7lRGtbJYFwhz+9OQaCs60kTl8AW3k6nnTK0sPX+8Zg4/vOfwWLTJc+kwHOyEDlJA=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': '00tEbVt/wGh7lRGtbJYFwhz+9OQaCs60kTl8AW3k6nnTK0sPX+8Zg4/vOfwWLTJc+kwHOyEDlJA=',
#    'x-amz-request-id': '9XXVB722VK42KZJN',
#    'date': 'Sun, 18 Apr 2021 15:38:14 GMT',
#    'etag': '"c3e99b11cd9ecf2d0fbe64122c32a476"',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'ETag': '"c3e99b11cd9ecf2d0fbe64122c32a476"'}

# %% [markdown]
# ##### Downloading data from s3 and unpickling

# %%
res_xx = s3.get_object(
    Bucket=bucket_name,
    Key="test_pickle.pkl"
)
res_xx
# Out:
# {'ResponseMetadata': {'RequestId': '1XRWXCT66KF3AZCT',
#   'HostId': 'u59a8VUy9a2oMgX0MU6Y08J6AMWTpThiupWcxbw+DGNPS7geSnU4U5Hl3chcGsZgnBRTlQXawPQ=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'u59a8VUy9a2oMgX0MU6Y08J6AMWTpThiupWcxbw+DGNPS7geSnU4U5Hl3chcGsZgnBRTlQXawPQ=',
#    'x-amz-request-id': '1XRWXCT66KF3AZCT',
#    'date': 'Sun, 18 Apr 2021 15:38:29 GMT',
#    'last-modified': 'Sun, 18 Apr 2021 15:38:14 GMT',
#    'etag': '"c3e99b11cd9ecf2d0fbe64122c32a476"',
#    'accept-ranges': 'bytes',
#    'content-type': 'binary/octet-stream',
#    'content-length': '8742',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'AcceptRanges': 'bytes',
#  'LastModified': datetime.datetime(2021, 4, 18, 15, 38, 14, tzinfo=tzutc()),
#  'ContentLength': 8742,
#  'ETag': '"c3e99b11cd9ecf2d0fbe64122c32a476"',
#  'ContentType': 'binary/octet-stream',
#  'Metadata': {},
#  'Body': <botocore.response.StreamingBody at 0x16ce6ce20>}

# %%
body = res_xx["Body"].read()

# %%
pickle.loads(body)
# Out:
# [{'inspection_id': '2498114',
#   'dba_name': 'CELTIC CROWN',
#   'aka_name': 'CELTIC CROWN',
#   'license_': '404',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '4301 N WESTERN AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60618',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Non-Inspection',
#   'results': 'No Entry',
#   'latitude': '41.959539275814876',
#   'longitude': '-87.68848380383307',
#   'location': {'latitude': '-87.68848380383307',
#    'longitude': '41.959539275814876'}},
#  {'inspection_id': '2498106',
#   'dba_name': 'ASIAN CUISINE EXPRESS',
#   'aka_name': 'ASIAN CUISINE EXPRESS',
#   'license_': '2327198',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '3823 W 31ST ST ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60623',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass',
#   'latitude': '41.836838656288656',
#   'longitude': '-87.72053342728425',
#   'location': {'latitude': '-87.72053342728425',
#    'longitude': '41.836838656288656'}},
#  {'inspection_id': '2498093',
#   'dba_name': 'CHAPPELL SCHOOL',
#   'aka_name': 'CHAPPELL SCHOOL',
#   'license_': '22681',
#   'facility_type': 'School',
#   'risk': 'Risk 1 (High)',
#   'address': '2135 W Foster AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60625',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Canvass Re-Inspection',
#   'results': 'Fail',
#   'violations': "10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: 5-202.12(A)  OBSERVED NO HOT WATER PROVIDED AT THE HAND WASHING SINK IN THE 2ND FLOOR GIRLS' WASHROOM IN THE NEW BUILDING.  THE WATER TEMPERATURE AT THE HAND WASHING SINK WAS AT 58F.  MANAGEMENT INSTRUCTED TO PROVIDE HOT WATER ABOVE 100F AT ALL HAND WASHING SINKS.  PRIORITY 7-38-030(C). | 38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: 6-501.111  OBSERVED EVIDENCE OF PEST ACTIVITY IN THE CLASSROOMS.  OBSERVED 10 MOUSE DROPPINGS IN THE BOTTOM SHELF OF THE WOODEN ART CABINET IN ROOM 107. MANAGEMENT INSTRUCTED TO CLEAN AND REMOVE ALL RODENT DROPPINGS FROM ALL AFFECTED AREAS. ADDITIONAL PEST CONTROL SERVICE IS NEEDED TO ELIMINATE THE PEST ACTIVITY FROM THE BUILDING. PRIORITY FOUNDATION 7-38-020(A).",
#   'latitude': '41.97586700298142',
#   'longitude': '-87.68325437820378',
#   'location': {'latitude': '-87.68325437820378',
#    'longitude': '41.97586700298142'}},
#  {'inspection_id': '2498087',
#   'dba_name': 'CARL VON LINNE ELEMENTARY SCHOOL',
#   'aka_name': 'CARL VON LINNE ELEMENTARY SCHOOL',
#   'license_': '24201',
#   'facility_type': 'School',
#   'risk': 'Risk 1 (High)',
#   'address': '3221 N SACRAMENTO BLVD ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60618',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Fail',
#   'violations': "10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: OBSERVED HANDSINK IN SHARED TOILET ROOM PRE-K CLASSROOM #128 AND #130  NOT STOCKED WITH HAND SOAP. INFORMED PERSON IN CHARGE THAT HAND SOAP MUST BE AVAILABLE AT HANDSINKS AT ALL TIMES. THE TEACHER OBTAINED HAND SOAP FOR HAND SINK DURING TIME OF INSPECTION. PRIORITY FOUNDATION VIOLATION #7-38-030(C). NO CITATION ISSUED. | 38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: OBSERVED NO CURRENT PEST CONTROL LOG BOOK ON THE PREMISES. INSTRUCTED PERSON IN CHARGE THAT A LICENSED PEST CONTROL COMPANY AND OPERATOR MUST PROVIDE AT LEAST 2 PEST INSPECTIONS A YEAR AND THE REPORTS MUST BE MAINTAINED IN THE LOG BOOK. INSTRUCTED TO PROVIDE A CURRENT PEST CONTROL LOG BOOK AND PEST INSPECTION REPORT.  PRIORITY FOUNDATION 7-38-020(C). NO CITATION ISSUED. | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: OBSERVED RUSTY SHELVES IN THE WALK-IN COOLER. MUST BE SMOOTH, AND EASILY CLEANABLE SURFACES. | 51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICES - Comments: OBSERVED THE TWO FAUCET HANDLES AT THE HAND SINK IN THE TEACHER'S LOUNGE TO HAVE A LEAK. INSTRUCTED TO REPAIR.",
#   'latitude': '41.94001885475702',
#   'longitude': '-87.70259824915517',
#   'location': {'latitude': '-87.70259824915517',
#    'longitude': '41.94001885475702'}},
#  {'inspection_id': '2498082',
#   'dba_name': 'THE BREWERY',
#   'aka_name': 'THE BREWERY',
#   'license_': '2551384',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '3848 N HARLEM AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60634',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Non-Inspection',
#   'results': 'No Entry',
#   'latitude': '41.95034769269968',
#   'longitude': '-87.80732944580947',
#   'location': {'latitude': '-87.80732944580947',
#    'longitude': '41.95034769269968'}},
#  {'inspection_id': '2498132',
#   'dba_name': 'JAYAKA CORPORATION',
#   'aka_name': 'MR. SUBMARINE',
#   'license_': '2781330',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '47 N WELLS ST ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60606',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'License',
#   'results': 'Pass',
#   'violations': '36. THERMOMETERS PROVIDED & ACCURATE - Comments: MISSING AND INACCURATE THERMOMOETR FOR WALK-IN AND PREP COOLERS, INSTRUCTED TO INSTALL. | 44. UTENSILS, EQUIPMENT & LINENS: PROPERLY STORED, DRIED, & HANDLED - Comments: UTENSILS NOT PROPERLY AIR DRIED, INSTRUCTED MANAGER TO AIR DRY ALL MULTI-USE UENSILS AFTER WASHING. | 45. SINGLE-USE/SINGLE-SERVICE ARTICLES: PROPERLY STORED & USED - Comments: USING NOT FOOD GRADE CONTAINERS WITH CHIPPED EDGES, INSTURED TO USE DURABLE FOOD GRADE CONTAINERS. | 51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICES - Comments: UNABLE TO LOCATE BACKFLOW PREVENTION DEVICE FOR ICE MAKER IN BASEMENT. INSTRUCTED TO INSTALL. | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: MISSING LIGHT SHIELDS FOR CEILING FIXTURE OF BASEMENT PREP AREA. INSTRUCTED TO INSTALL.',
#   'latitude': '41.883131152793595',
#   'longitude': '-87.63371346963126',
#   'location': {'latitude': '-87.63371346963126',
#    'longitude': '41.883131152793595'}},
#  {'inspection_id': '2498123',
#   'dba_name': 'CHIPOTLE MEXICAN GRILL',
#   'aka_name': 'CHIPOTLE MEXICAN GRILL',
#   'license_': '2109272',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '2809 N ASHLAND AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60657',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass',
#   'latitude': '41.93270303163393',
#   'longitude': '-87.66825941420389',
#   'location': {'latitude': '-87.66825941420389',
#    'longitude': '41.93270303163393'}},
#  {'inspection_id': '2498105',
#   'dba_name': 'BAR CAFE SAN FRANCESCO',
#   'aka_name': 'BAR CAFE SAN FRANCESCO',
#   'license_': '17161',
#   'facility_type': 'Restaurant',
#   'risk': 'Risk 1 (High)',
#   'address': '3815 N HARLEM AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60634',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass',
#   'violations': "10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: INSTRUCTED TO PROVIDE AND MAINTAIN HANDWASHING SIGNAGE AT ALL HANDSINKS(BAR,WASHROOM). | 38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: OBSERVED FRONT SCREEN DOOR WITH GAP APPROXIMATELY 1/4' INCH OPENING AT BOTTOM LEFT CORNER.MUST MAKE DOOR TIGHT FITTING ALL ACROSS THE BOTTOM TO PREVENT PEST ENTRY. | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: INSTRUCTED NOT TO USE GROCERY BAGS FOR FOOD STORAGE INSIDE REFRIGERATION UNITS. MUST USE FOOD GRADE STORAGE BAGS OR CONTAINERS.  | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: OBSERVED MISSING SINK STOPPERS FOR THE BAR 3-COMPARTMENT SINK.INSTRUCTED TO PROVIDE AND MAINTAIN 3 ADEQUATE WORKING SINK STOPPERS.  | 49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: INSTRUCTED TO DETAIL CLEAN AND MAINTAIN THE FOLLOWING: INTERIOR AND EXTERIOR SURFACES OF ALL COOLERS AND FREEZERS,PREP TABLES,STORAGE AND PREP SHELVES, INTERIOR AND EXTERIOR SURFACES OF 3-COMPARTMENT SINK.  | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: INSTRUCTED TO DETAIL CLEAN AND MAINTAIN FLOORS WITH FOOD DEBRIS AND SOME LITTER ALONG THE WALLS AND IN ALL CORNERS THROUGHOUT REAR KITCHEN PREP AREA AND IN THE FRONT BAR AREA.  | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: INSTRUCTED TO DETAIL CLEAN AND ORGANIZE KITCHEN PREP AREA AND FRONT BAR AREA AND REMOVE UNNECESSARY ARTICLES DUE TO POTENTIAL PEST HARBORAGE AND ELEVATE STOCK ITEMS OFF THE FLOOR AT LEAST 6' INCHES (MUST NOT USE MILK CRATES OR SODA CRATES FOR ELEVATING OF ITEMS).  | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: INSTRUCTED TO REMOVE ACCUMULATION OF DUSTS ON VENTILATION COVER IN WASHROOMS.",
#   'latitude': '41.94938961660852',
#   'longitude': '-87.80700291252472',
#   'location': {'latitude': '-87.80700291252472',
#    'longitude': '41.94938961660852'}},
#  {'inspection_id': '2498081',
#   'dba_name': 'HOUSE OF KIDS DAYCARE',
#   'aka_name': 'HOUSE OF KIDS',
#   'license_': '2215884',
#   'facility_type': "Children's Services Facility",
#   'risk': 'Risk 1 (High)',
#   'address': '7158 W ADDISON ST ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60634',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass',
#   'violations': '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: OBSERVED ALUMINUM FOIL LINERS ON KITCHEN COOKING STOVE.MUST REMOVE ALUMINUM FOIL LINERS AND MAINTAIN TO SMOOTH,EASILY CLEANABLE SURFACES. | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: OBSERVED BURNT-OUT LIGHT BULBS IN STUDENTS WASHROOM AND AT FRONT OFFICE AREA.MUST PROVIDE AND MAINTAIN ADEQUATE LIGHTING AT ALL TIMES.',
#   'latitude': '41.94539701438075',
#   'longitude': '-87.80571712400827',
#   'location': {'latitude': '-87.80571712400827',
#    'longitude': '41.94539701438075'}},
#  {'inspection_id': '2498086',
#   'dba_name': 'ELSIETECATERING',
#   'aka_name': 'ELSIETECATERING',
#   'license_': '2663526',
#   'facility_type': 'Catering',
#   'risk': 'Risk 1 (High)',
#   'address': '3817 S KEDZIE AVE ',
#   'city': 'CHICAGO',
#   'state': 'IL',
#   'zip': '60632',
#   'inspection_date': '2021-04-12T00:00:00.000',
#   'inspection_type': 'Canvass',
#   'results': 'Pass',
#   'violations': '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: RAW WOOD STORAGE SHELVES ON SITE. INSTD TO SEAL/PAINT SAME SO AS BE A NON POROUS, EASILY CLEANABLE SURFACE | 53. TOILET FACILITIES: PROPERLY CONSTRUCTED, SUPPLIED, & CLEANED - Comments: MISSING COVER FOR RECEPTACLES IN TOILET. INSTD TO PROVIDE COVERS AND MAINTAIN',
#   'latitude': '41.82381861968802',
#   'longitude': '-87.70428542093514',
#   'location': {'latitude': '-87.70428542093514',
#    'longitude': '41.82381861968802'}}]

# %% [markdown]
# #### Uploading info

# %% [raw]
# # guardar_ingesta(bucket_name, hist_ingest_path)
# guardar_ingesta(bucket_name, cont_ingest_path)

# %% [markdown]
# #### Checking aws s3 contents

# %%
s3 = get_s3_resource()
# Out:
# --------
# FileNotFoundErrorTraceback (most recent call last)
# ~/Documents/ReposRob_RobPer/ITAMmcd/semestre_2/Arquitectura_Prod_Dat/Venv_ArqPD/repos/dpa_2021/src/utils/utils.py in read_yaml_file(yaml_file)
#     153     try:
# --> 154         with open (yaml_file, 'r') as f:
#     155             config = yaml.safe_load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'conf/local/credentials.yaml'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundErrorTraceback (most recent call last)
# <ipython-input-5-5dd7f3a14a67> in <module>
# ----> 1 s3 = get_s3_resource()
#
# ~/Documents/ReposRob_RobPer/ITAMmcd/semestre_2/Arquitectura_Prod_Dat/Venv_ArqPD/repos/dpa_2021/src/utils/utils.py in get_s3_resource()
#     203     """
#     204
# --> 205     s3_creds = get_s3_credentials("conf/local/credentials.yaml")
#     206
#     207     session = boto3.Session(
#
# ~/Documents/ReposRob_RobPer/ITAMmcd/semestre_2/Arquitectura_Prod_Dat/Venv_ArqPD/repos/dpa_2021/src/utils/utils.py in get_s3_credentials(credentials_file)
#     166     Get s3 credentials
#     167     """
# --> 168     credentials = read_yaml_file(credentials_file)
#     169     s3_creds = credentials['s3']
#     170
#
# ~/Documents/ReposRob_RobPer/ITAMmcd/semestre_2/Arquitectura_Prod_Dat/Venv_ArqPD/repos/dpa_2021/src/utils/utils.py in read_yaml_file(yaml_file)
#     155             config = yaml.safe_load(f)
#     156     except:
# --> 157         raise FileNotFoundError('Couldnt load the file')
#     158
#     159     return config
#
# FileNotFoundError: Couldnt load the file

# %%
cont_ingest_path

# %%
objects = s3.list_objects_v2(Bucket=bucket_name, Prefix=cont_ingest_path)['Contents']
objects

# %%
objects.append(
 {'Key': 'ingestion/consecutive/consecutive-inspections-2021-02-22.pkl',
  'LastModified': "datetime.datetime(2021, 2, 22, 2, 53, 54, tzinfo=tzutc())",
  'ETag': '"79cff7864a646f1dfd4d51b4e732a226"',
  'Size': 1152660,
  'StorageClass': 'STANDARD'}
)

objects.append(
 {'Key': 'ingestion/consecutive/consecutive-inspections-2021-02-15.pkl',
  'LastModified': "datetime.datetime(2021, 2, 22, 2, 53, 54, tzinfo=tzutc())",
  'ETag': '"79cff7864a646f1dfd4d51b4e732a226"',
  'Size': 1152660,
  'StorageClass': 'STANDARD'}
)

objects.append(
 {'Key': 'ingestion/consecutive/consecutive-inspections-2021-02-10.pkl',
  'LastModified': "datetime.datetime(2021, 2, 22, 2, 53, 54, tzinfo=tzutc())",
  'ETag': '"79cff7864a646f1dfd4d51b4e732a226"',
  'Size': 1152660,
  'StorageClass': 'STANDARD'}
)

# %%
rex = str(cont_dat_prefix) + "(.*).pkl"

lx = [datetime.strptime(re.search(rex, obj["Key"]).group(1), '%Y-%m-%d') for obj in objects if cont_dat_prefix in obj["Key"]]
most_rec_date = datetime.strftime(max(lx), '%Y-%m-%d')
most_rec_date

# %%
s3x = pickle.loads(s3.get_object(Bucket=bucket_name, Key=(cont_ingest_path + "consecutive-inspections-2021-02-21.pkl"))['Body'].read())

# %% [raw]
# s3x

# %%
dfx = pd.DataFrame(s3x)
dfx

# %%
dfx["inspection_date"] = pd.to_datetime(dfx["inspection_date"])

# %%
print("max date: ", max(dfx["inspection_date"]))
print("min date: ", min(dfx["inspection_date"]))

# %%
dfx.groupby(pd.Grouper(key="inspection_date")).count()[["inspection_id"]]

# %% [markdown]
# ---

# %% [markdown]
# ## Creating local directories for temporal data

# %%
base_path = "../src/pipeline/luigi/ingestion_tmp/"

# %% [markdown]
# ### Find most recent ingestion

# %% [markdown]
# #### Case 1: There is previous consecutive downloads

# %%
lyrs = [ydir[-4:] for ydir in os.listdir(base_path + "consecutive") if "YEAR=" in ydir]
lyrs

# %%
mr_yr = max(lyrs)
mr_yr

# %%
lmths = [mdir[-2:] for mdir in os.listdir(base_path + "consecutive" + "/" + "YEAR=" + mr_yr) if "MONTH=" in mdir]
lmths

# %%
mr_mth = max(lmths)
mr_mth

# %%
lings = [ing for ing in os.listdir(base_path + "consecutive" + "/" + "YEAR=" + mr_yr + "/" + "MONTH=" + mr_mth)]
lings

# %% [raw]
# lings = ['consecutive_inspections_2021-03-05.pkl',
#  'consecutive_inspections_2021-03-10.pkl',
#  'consecutive_inspections_2021-03-16.pkl',
#  'consecutive_inspections_2021-02-11.pkl',
#  'consecutive_inspections_2021-02-04.pkl',
#  'consecutive_inspections_2020-12-25.pkl'
#         ]
# lings

# %%
regex = "consecutive_inspections_" + "(.*).pkl"

# %%
min([re.search(regex, ing).group(1) for ing in lings])

# %%
lx = ['.DS_Store', 'consecutive_inspections_2021-03-05.pkl', 'consecutive_inspections_2021-03-10.pkl']
lx

# %%
cont_dat_prefix = "consecutive_inspections_"

# %%
regex = cont_dat_prefix + "(.*).pkl"

# %%
lx

# %%
lings

# %%
most_recent_ing = max([re.search(regex, ing).group(1) for ing in lx if ".pkl" in ing])
most_recent_ing

# %% [markdown]
# #### Additional notes

# %%
x = date.today().strftime('%Y-%m-%d')

# %%
x[5:7]

# %% [markdown]
# ---

# %% [markdown]
# ## Creating .csv files with metadata

# %% [markdown]
# ### Loading previous metadata pickle

# %%
pkl_meta = "../results/metadata/transform_metadata.pkl"

# %%
pickle.load(open(pkl_meta, "rb"))
# Out:
#                            trans_count            new_cols
# ing_time_exec
# 2021-04-12 18:11:08.664824           2  serious_violations

# %% [markdown]
# ### Creating dummy metadata

# %% [markdown]
# #### Line 1

# %%
meta_1 = str(datetime.now())

# %%
meta_2 = str(2)

# %%
meta_3 = "serious_violations"

# %%
meta_comp = ",".join([meta_1, meta_2, meta_3])
meta_comp
# Out:
# '2021-04-18 11:24:44.839666,2,serious_violations'

# %%
import csv
with open("transformation_metadata.csv", mode="w") as metadata_file:
    metadata_writer = csv.writer(metadata_file, delimiter=",", quotechar='"', quoting=csv.QUOTE_MINIMAL)
    metadata_writer.writerow([meta_1, meta_2, meta_3])

# %% [markdown]
# ---
# ---
